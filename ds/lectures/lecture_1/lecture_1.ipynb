# %% [markdown]
# # Технологии искусственного интеллекта. Анализ данных
#
# © Петров М.В., старший преподаватель кафедры киберфотоники, Самарский университет
#
# План:
# 1. Библиотека Pandas. Визуализация данных
# 2. Задачи классификации. Метрики качества. Классификация *kNN*
# 3. Деревья решений
# 4. Линейная регрессия. Метрики качества
# 5. Градиентный бустинг
# 6. **[TBA]**
#
# ## Лекция 1. Библиотека Pandas. Визуализация данных
#
# ### Содержание
#
# 1. [Введение](#1.1-Введение)
# 2. [Pandas](#1.2-Pandas)
# 3. [Предобработка данных](#1.3-Предобработка-данных)
# 4. [Визуализация данных](#1.4-Визуализация-данных)
# 5. [Датасет](#1.5-Датасет)
# 6. [Предобработка данных датасета](#1.6-Предобработка-данных-датасета)
# 7. [Интерактивный график в `matplotlib`](#1.7-Интерактивный-график-в-matplotlib)
# 8. [Интерактивный график в `plotly`](#1.8-Интерактивный-график-в-plotly)
# 9. [Построение графиков средствами `pandas`](#1.9-Построение-графиков-средствами-`pandas`)
# 10. [Построение графиков в `seaborn`](#1.10-Построение-графиков-в-seaborn)
# 11. [Построение различных графиков](#1.11-Построение-различных-графиков)
# 12. [Экспорт в растровый и векторный форматы](#1.12-Экспорт-в-растровый-и-векторный-форматы)
# 13. [`plotly` `Dash`](#1.13-plotly-Dash)
#
# ### 1.1 Введение
#
# Что потребуется:
# - [Python 3](https://www.python.org/)
# - Библиотеки:
#   - [NumPy](https://numpy.org/)
#   - [SciPy](https://scipy.org/)
#   - [Pandas](https://pandas.pydata.org/)
#   - [Matplotlib](https://matplotlib.org/)
#   - [Plotly](https://plotly.com/python/)
#   - [Scikit-learn](https://scikit-learn.org/stable/)
#   - [CatBoost](https://catboost.ai/)
#   - [Jupyter Notebook или JupyterLab](https://jupyter.org/)
#   - [kagglehub](https://pypi.org/project/kagglehub/)
# - Настроенная IDE
#
# Подробнее:
# - [Установка Python. Менеджеры пакетов. Виртуальное окружение. Настройка IDE](../../self-study/python_stuff.md).

# %% [markdown]
# ### 1.2 Pandas
# `pandas` &ndash; это высокоуровневая Python библиотека для работы с табличными данными.
#
# Гайды:
# - [pandas User Guide](https://pandas.pydata.org/docs/user_guide/index.html)
# - [pandas API reference](https://pandas.pydata.org/docs/reference/index.html)
# - [Открытый курс машинного обучения. Тема 1. Первичный анализ данных с Pandas](https://habr.com/company/ods/blog/322626/)

# %%
# !python -V
# Out:
# Python 3.14.3

# %%
import pandas as pd
pd.__version__
# Out:
# '3.0.0'

# %%
from pathlib import Path
# путь к папке с данными
data_path = "data"
# Чтение данных из csv-файла
# датасет: Goodreads Books - 31 Features: https://www.kaggle.com/datasets/austinreese/goodreads-books
data = pd.read_csv(Path(data_path, 'goodreads_books.csv'))
type(data)
# Out:
# pandas.DataFrame

# %% [markdown]
# > [DataFrame](https://pandas.pydata.org/docs/reference/frame.html) - Two-dimensional, size-mutable, potentially heterogeneous tabular data.

# %% [markdown]
# Скачивание датасета с использованием `kagglehub`:

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("austinreese/goodreads-books")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\UD\.cache\kagglehub\datasets\austinreese\goodreads-books\versions\1

# %%
# возвращает первые n строк, n=5 по-умолчанию
data.head()
# Out:
#         id                                              title  \
# 0   630104                                       Inner Circle
# 1     9487                                  A Time to Embrace
# 2  6050894                                           Take Two
# 3    39030                                          Reliquary
# 4      998  The Millionaire Next Door: The Surprising Secr...
#
#                                                 link               series  \
# 0  https://www.goodreads.com//book/show/630104.In...         (Private #5)
# 1  https://www.goodreads.com//book/show/9487.A_Ti...   (Timeless Love #2)
# 2  https://www.goodreads.com//book/show/6050894-t...  (Above the Line #2)
# 3  https://www.goodreads.com//book/show/39030.Rel...      (Pendergast #2)
# 4  https://www.goodreads.com//book/show/998.The_M...                  NaN
#
#                                           cover_link  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...
# 1  https://i.gr-assets.com/images/S/compressed.ph...
# 2  https://i.gr-assets.com/images/S/compressed.ph...
# 3  https://i.gr-assets.com/images/S/compressed.ph...
# 4  https://i.gr-assets.com/images/S/compressed.ph...
#
#                                 author  \
# 0            Kate Brian, Julian Peploe
# 1                      Karen Kingsbury
# 2                      Karen Kingsbury
# 3       Douglas Preston, Lincoln Child
# 4  Thomas J. Stanley, William D. Danko
#
#                                          author_link  rating_count  \
# 0  https://www.goodreads.com/author/show/94091.Ka...          7597
# 1  https://www.goodreads.com/author/show/3159984....          4179
# 2  https://www.goodreads.com/author/show/3159984....          6288
# 3  https://www.goodreads.com/author/show/12577.Do...         38382
# 4  https://www.goodreads.com/author/show/659.Thom...         72168
#
#    review_count  average_rating  ...         isbn13  asin  \
# 0           196            4.03  ...  9781416950417   NaN
# 1           177            4.35  ...  9781595542328   NaN
# 2           218            4.23  ...            NaN   NaN
# 3          1424            4.01  ...  9780765354952   NaN
# 4          3217            4.04  ...  9780671015206   NaN
#
#                                             settings  \
# 0                                                NaN
# 1                                                NaN
# 2                Bloomington, Indiana(United States)
# 3  New York State(United States) New York City, N...
# 4                                                NaN
#
#                                           characters  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Aloysius X.L. Pendergast, Margo Green, William...
# 4                                                NaN
#
#                                               awards  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Independent Publisher Book Award (IPPY) Nomine...
#
#                                 amazon_redirect_link  \
# 0  https://www.goodreads.com//book_link/follow/17...
# 1  https://www.goodreads.com//book_link/follow/17...
# 2  https://www.goodreads.com//book_link/follow/17...
# 3  https://www.goodreads.com//book_link/follow/17...
# 4  https://www.goodreads.com//book_link/follow/17...
#
#                               worldcat_redirect_link  \
# 0  https://www.goodreads.com//book_link/follow/8?...
# 1  https://www.goodreads.com//book_link/follow/8?...
# 2  https://www.goodreads.com//book_link/follow/8?...
# 3  https://www.goodreads.com//book_link/follow/8?...
# 4  https://www.goodreads.com//book_link/follow/8?...
#
#                                    recommended_books  \
# 0  726458, 726458, 1537534, 3047848, 1651302, 304...
# 1  127352, 127352, 40642197, 127353, 127354, 3891...
# 2  706250, 706250, 666481, 11942636, 706241, 1273...
# 3  39026, 39026, 11007668, 3986318, 51887330, 194...
# 4  1052, 1052, 763362, 69571, 78427, 30186948, 10...
#
#                                      books_in_series  \
# 0  381489, 381501, 352428, 630103, 1783281, 17832...
# 1                                             115036
# 2                         4010795, 40792877, 7306261
# 3  67035, 39031, 39033, 136637, 136638, 30068, 39...
# 4                                                NaN
#
#                                          description
# 0  Reed Brennan arrived at Easton Academy expecti...
# 1  Ideje az Ã¶lelÃ©snek TÃ¶rtÃ©net a remÃ©nyrÅl,...
# 2  Filmmakers Chase Ryan and Keith Ellison have c...
# 3                                                NaN
# 4  The incredible national bestseller that is cha...
#
# [5 rows x 31 columns]

# %% [markdown]
# [Pandas options and settings](https://pandas.pydata.org/pandas-docs/stable/reference/options.html):
# - `display.max_columnsint`
#     If max_cols is exceeded, switch to truncate view. Depending on large_repr, objects are either centrally truncated or printed as a summary view. ‘None’ value means unlimited.
#     In case python/IPython is running in a terminal and large_repr equals ‘truncate’ this can be set to 0 or None and pandas will auto-detect the width of the terminal and print a truncated object which fits the screen width. The IPython notebook, IPython qtconsole, or IDLE do not run in a terminal and hence it is not possible to do correct auto-detection and defaults to 20.

# %%
# вывод всех столбцов датафрейма - None
pd.set_option('display.max_columns', None)

# %%
data.head()
# Out:
#         id                                              title  \
# 0   630104                                       Inner Circle
# 1     9487                                  A Time to Embrace
# 2  6050894                                           Take Two
# 3    39030                                          Reliquary
# 4      998  The Millionaire Next Door: The Surprising Secr...
#
#                                                 link               series  \
# 0  https://www.goodreads.com//book/show/630104.In...         (Private #5)
# 1  https://www.goodreads.com//book/show/9487.A_Ti...   (Timeless Love #2)
# 2  https://www.goodreads.com//book/show/6050894-t...  (Above the Line #2)
# 3  https://www.goodreads.com//book/show/39030.Rel...      (Pendergast #2)
# 4  https://www.goodreads.com//book/show/998.The_M...                  NaN
#
#                                           cover_link  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...
# 1  https://i.gr-assets.com/images/S/compressed.ph...
# 2  https://i.gr-assets.com/images/S/compressed.ph...
# 3  https://i.gr-assets.com/images/S/compressed.ph...
# 4  https://i.gr-assets.com/images/S/compressed.ph...
#
#                                 author  \
# 0            Kate Brian, Julian Peploe
# 1                      Karen Kingsbury
# 2                      Karen Kingsbury
# 3       Douglas Preston, Lincoln Child
# 4  Thomas J. Stanley, William D. Danko
#
#                                          author_link  rating_count  \
# 0  https://www.goodreads.com/author/show/94091.Ka...          7597
# 1  https://www.goodreads.com/author/show/3159984....          4179
# 2  https://www.goodreads.com/author/show/3159984....          6288
# 3  https://www.goodreads.com/author/show/12577.Do...         38382
# 4  https://www.goodreads.com/author/show/659.Thom...         72168
#
#    review_count  average_rating  five_star_ratings  four_star_ratings  \
# 0           196            4.03               3045               2323
# 1           177            4.35               2255               1290
# 2           218            4.23               3000               2020
# 3          1424            4.01              12711              15407
# 4          3217            4.04              27594              25219
#
#    three_star_ratings  two_star_ratings  one_star_ratings  number_of_pages  \
# 0                1748               389                92            220.0
# 1                 518                93                23            400.0
# 2                1041               183                44            320.0
# 3                8511              1429               324            464.0
# 4               14855              3414              1086            258.0
#
#       date_published                                publisher  \
# 0   January 1st 2007  Simon  Schuster Books for Young Readers
# 1  October 29th 2006                            Thomas Nelson
# 2   January 1st 2009                                Zondervan
# 3               1997                                Tor Books
# 4  October 28th 1995                            Gallery Books
#
#                                       original_title  \
# 0                                       Inner Circle
# 1                                                NaN
# 2                                           Take Two
# 3                                          Reliquary
# 4  The Millionaire Next Door: The Surprising Secr...
#
#                                      genre_and_votes        isbn  \
# 0            Young Adult 161, Mystery 45, Romance 32  1416950419
# 1  Christian Fiction 114, Christian 45, Fiction 3...  1595542329
# 2    Christian Fiction 174, Christian 81, Fiction 58         NaN
# 3  Thriller 626, Mystery 493, Horror 432, Fiction...  0765354950
# 4  Economics-Finance 1162, Nonfiction 910, Busine...  0671015206
#
#           isbn13 asin                                           settings  \
# 0  9781416950417  NaN                                                NaN
# 1  9781595542328  NaN                                                NaN
# 2            NaN  NaN                Bloomington, Indiana(United States)
# 3  9780765354952  NaN  New York State(United States) New York City, N...
# 4  9780671015206  NaN                                                NaN
#
#                                           characters  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Aloysius X.L. Pendergast, Margo Green, William...
# 4                                                NaN
#
#                                               awards  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Independent Publisher Book Award (IPPY) Nomine...
#
#                                 amazon_redirect_link  \
# 0  https://www.goodreads.com//book_link/follow/17...
# 1  https://www.goodreads.com//book_link/follow/17...
# 2  https://www.goodreads.com//book_link/follow/17...
# 3  https://www.goodreads.com//book_link/follow/17...
# 4  https://www.goodreads.com//book_link/follow/17...
#
#                               worldcat_redirect_link  \
# 0  https://www.goodreads.com//book_link/follow/8?...
# 1  https://www.goodreads.com//book_link/follow/8?...
# 2  https://www.goodreads.com//book_link/follow/8?...
# 3  https://www.goodreads.com//book_link/follow/8?...
# 4  https://www.goodreads.com//book_link/follow/8?...
#
#                                    recommended_books  \
# 0  726458, 726458, 1537534, 3047848, 1651302, 304...
# 1  127352, 127352, 40642197, 127353, 127354, 3891...
# 2  706250, 706250, 666481, 11942636, 706241, 1273...
# 3  39026, 39026, 11007668, 3986318, 51887330, 194...
# 4  1052, 1052, 763362, 69571, 78427, 30186948, 10...
#
#                                      books_in_series  \
# 0  381489, 381501, 352428, 630103, 1783281, 17832...
# 1                                             115036
# 2                         4010795, 40792877, 7306261
# 3  67035, 39031, 39033, 136637, 136638, 30068, 39...
# 4                                                NaN
#
#                                          description
# 0  Reed Brennan arrived at Easton Academy expecti...
# 1  Ideje az Ã¶lelÃ©snek TÃ¶rtÃ©net a remÃ©nyrÅl,...
# 2  Filmmakers Chase Ryan and Keith Ellison have c...
# 3                                                NaN
# 4  The incredible national bestseller that is cha...

# %%
# размерностть
data.shape
# Out:
# (52199, 31)

# %%
# информация о данных в DataFrame, тип данных признаков
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 52199 entries, 0 to 52198
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      52199 non-null  int64
#  1   title                   52199 non-null  str
#  2   link                    52199 non-null  str
#  3   series                  23319 non-null  str
#  4   cover_link              51592 non-null  str
#  5   author                  52199 non-null  str
#  6   author_link             52199 non-null  str
#  7   rating_count            52199 non-null  int64
#  8   review_count            52199 non-null  int64
#  9   average_rating          52199 non-null  float64
#  10  five_star_ratings       52199 non-null  int64
#  11  four_star_ratings       52199 non-null  int64
#  12  three_star_ratings      52199 non-null  int64
#  13  two_star_ratings        52199 non-null  int64
#  14  one_star_ratings        52199 non-null  int64
#  15  number_of_pages         49869 non-null  float64
#  16  date_published          51339 non-null  str
#  17  publisher               48563 non-null  str
#  18  original_title          39250 non-null  str
#  19  genre_and_votes         49359 non-null  str
#  20  isbn                    40316 non-null  str
#  21  isbn13                  39507 non-null  str
#  22  asin                    5236 non-null   str
#  23  settings                11515 non-null  str
#  24  characters              13695 non-null  str
#  25  awards                  10626 non-null  str
#  26  amazon_redirect_link    52199 non-null  str
#  27  worldcat_redirect_link  48214 non-null  str
#  28  recommended_books       48205 non-null  str
#  29  books_in_series         22078 non-null  str
#  30  description             49624 non-null  str
# dtypes: float64(2), int64(8), str(21)
# memory usage: 12.3 MB

# %%
# статистика по числовым признакам
data.describe()
# Out:
#                  id  rating_count   review_count  average_rating  \
# count  5.219900e+04  5.219900e+04   52199.000000    52199.000000
# mean   1.015443e+07  1.887361e+04    1012.980881        4.020610
# std    1.164443e+07  1.163978e+05    4054.802421        0.367161
# min    1.000000e+00  0.000000e+00       0.000000        0.000000
# 25%    3.628190e+05  3.400000e+02      31.000000        3.820000
# 50%    6.383537e+06  2.295000e+03     163.000000        4.030000
# 75%    1.738060e+07  9.297500e+03     622.000000        4.230000
# max    5.444299e+07  6.801077e+06  169511.000000        5.000000
#
#        five_star_ratings  four_star_ratings  three_star_ratings  \
# count       5.219900e+04       5.219900e+04        52199.000000
# mean        7.817176e+03       6.250785e+03         3456.512424
# std         5.876373e+04       3.473533e+04        18249.298631
# min         0.000000e+00       0.000000e+00            0.000000
# 25%         1.170000e+02       1.090000e+02           63.000000
# 50%         8.100000e+02       7.650000e+02          452.000000
# 75%         3.375500e+03       3.190500e+03         1866.000000
# max         4.414877e+06       1.868421e+06       980183.000000
#
#        two_star_ratings  one_star_ratings  number_of_pages
# count      52199.000000      52199.000000     49869.000000
# mean         935.496600        413.640051       328.942730
# std         5890.077215       3843.356500       252.790119
# min            0.000000          0.000000         0.000000
# 25%           15.000000          6.000000       210.000000
# 50%          107.000000         36.000000       304.000000
# 75%          450.000000        151.000000       392.000000
# max       529060.000000     537793.000000     14777.000000

# %%
# убираем колонки в датафрейме по названию, изменяем состояние объекта - inplace=True
data.drop(columns=['settings', 'amazon_redirect_link', 'worldcat_redirect_link', 
                   'recommended_books', 'books_in_series', 'description', 'asin',
                   'link', 'author_link', 'cover_link','original_title'], inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 52199 entries, 0 to 52198
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  52199 non-null  int64
#  1   title               52199 non-null  str
#  2   series              23319 non-null  str
#  3   author              52199 non-null  str
#  4   rating_count        52199 non-null  int64
#  5   review_count        52199 non-null  int64
#  6   average_rating      52199 non-null  float64
#  7   five_star_ratings   52199 non-null  int64
#  8   four_star_ratings   52199 non-null  int64
#  9   three_star_ratings  52199 non-null  int64
#  10  two_star_ratings    52199 non-null  int64
#  11  one_star_ratings    52199 non-null  int64
#  12  number_of_pages     49869 non-null  float64
#  13  date_published      51339 non-null  str
#  14  publisher           48563 non-null  str
#  15  genre_and_votes     49359 non-null  str
#  16  isbn                40316 non-null  str
#  17  isbn13              39507 non-null  str
#  18  characters          13695 non-null  str
#  19  awards              10626 non-null  str
# dtypes: float64(2), int64(8), str(10)
# memory usage: 8.0 MB

# %%
data.describe()
# Out:
#                  id  rating_count   review_count  average_rating  \
# count  5.219900e+04  5.219900e+04   52199.000000    52199.000000
# mean   1.015443e+07  1.887361e+04    1012.980881        4.020610
# std    1.164443e+07  1.163978e+05    4054.802421        0.367161
# min    1.000000e+00  0.000000e+00       0.000000        0.000000
# 25%    3.628190e+05  3.400000e+02      31.000000        3.820000
# 50%    6.383537e+06  2.295000e+03     163.000000        4.030000
# 75%    1.738060e+07  9.297500e+03     622.000000        4.230000
# max    5.444299e+07  6.801077e+06  169511.000000        5.000000
#
#        five_star_ratings  four_star_ratings  three_star_ratings  \
# count       5.219900e+04       5.219900e+04        52199.000000
# mean        7.817176e+03       6.250785e+03         3456.512424
# std         5.876373e+04       3.473533e+04        18249.298631
# min         0.000000e+00       0.000000e+00            0.000000
# 25%         1.170000e+02       1.090000e+02           63.000000
# 50%         8.100000e+02       7.650000e+02          452.000000
# 75%         3.375500e+03       3.190500e+03         1866.000000
# max         4.414877e+06       1.868421e+06       980183.000000
#
#        two_star_ratings  one_star_ratings  number_of_pages
# count      52199.000000      52199.000000     49869.000000
# mean         935.496600        413.640051       328.942730
# std         5890.077215       3843.356500       252.790119
# min            0.000000          0.000000         0.000000
# 25%           15.000000          6.000000       210.000000
# 50%          107.000000         36.000000       304.000000
# 75%          450.000000        151.000000       392.000000
# max       529060.000000     537793.000000     14777.000000

# %%
# вывод данных колонки `title`
data['title']
# Out:
# 0                                             Inner Circle
# 1                                        A Time to Embrace
# 2                                                 Take Two
# 3                                                Reliquary
# 4        The Millionaire Next Door: The Surprising Secr...
#                                ...
# 52194                               The Stranger I Married
# 52195       The Opposite of Loneliness: Essays and Stories
# 52196                                    Sadako will leben
# 52197                                          Confessions
# 52198                        Going Rogue: An American Life
# Name: title, Length: 52199, dtype: str

# %%
type(data['title'])
# Out:
# pandas.Series

# %% [markdown]
# > [Series](https://pandas.pydata.org/docs/reference/series.html) - One-dimensional ndarray with axis labels (including time series).

# %%
data['title'].head(3)
# Out:
# 0         Inner Circle
# 1    A Time to Embrace
# 2             Take Two
# Name: title, dtype: str

# %% [markdown]
# #### Индексация

# %%
# срез с указанием признаков
data.loc[200:204, ['title', 'five_star_ratings']]
# Out:
#                                                  title  five_star_ratings
# 200                                    This is Falling               3923
# 201                             When My Name Was Keoko               1955
# 202  Farewell to Manzanar: A True Story of Japanese...               2379
# 203                                        Kissing Sin               6263
# 204                                          Havemercy                670

# %%
# срез numpy-like
data.iloc[200:204, 0:3]
# Out:
#            id                                              title  \
# 200  22756190                                    This is Falling
# 201    613218                             When My Name Was Keoko
# 202    649361  Farewell to Manzanar: A True Story of Japanese...
# 203     74043                                        Kissing Sin
#
#                          series
# 200                (Falling #1)
# 201                         NaN
# 202                         NaN
# 203  (Riley Jenson Guardian #2)

# %%
# фильтрация данных - маска
data['five_star_ratings'] > 2500
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 52194     True
# 52195     True
# 52196    False
# 52197     True
# 52198    False
# Name: five_star_ratings, Length: 52199, dtype: bool

# %%
# фильтрация данных по булевой маске
data[data['five_star_ratings'] > 2500]
# Out:
#              id                                              title  \
# 0        630104                                       Inner Circle
# 2       6050894                                           Take Two
# 3         39030                                          Reliquary
# 4           998  The Millionaire Next Door: The Surprising Secr...
# 5        311164                                        Black Sheep
# ...         ...                                                ...
# 52192  15727731                                    Beauty Awakened
# 52193   1395807                                        Blue Heaven
# 52194  15743072                             The Stranger I Married
# 52195  18143905     The Opposite of Loneliness: Essays and Stories
# 52197    630103                                        Confessions
#
#                         series                               author  \
# 0                 (Private #5)            Kate Brian, Julian Peploe
# 2          (Above the Line #2)                      Karen Kingsbury
# 3              (Pendergast #2)       Douglas Preston, Lincoln Child
# 4                          NaN  Thomas J. Stanley, William D. Danko
# 5                          NaN                      Georgette Heyer
# ...                        ...                                  ...
# 52192  (Angels of the Dark #2)                       Gena Showalter
# 52193                      NaN                             C.J. Box
# 52194                      NaN                           Sylvia Day
# 52195                      NaN                        Marina Keegan
# 52197             (Private #4)                           Kate Brian
#
#        rating_count  review_count  average_rating  five_star_ratings  \
# 0              7597           196            4.03               3045
# 2              6288           218            4.23               3000
# 3             38382          1424            4.01              12711
# 4             72168          3217            4.04              27594
# 5              9538           775            4.05               3298
# ...             ...           ...             ...                ...
# 52192         11894           793            4.15               5227
# 52193         11284          1096            4.01               3656
# 52194         13295           805            3.87               4220
# 52195         42609          4282            3.84              12461
# 52197          8815           258            4.09               3760
#
#        four_star_ratings  three_star_ratings  two_star_ratings  \
# 0                   2323                1748               389
# 2                   2020                1041               183
# 3                  15407                8511              1429
# 4                  25219               14855              3414
# 5                   3831                2042               304
# ...                  ...                 ...               ...
# 52192               4031                2032               453
# 52193               4752                2346               423
# 52194               4733                3116               848
# 52195              15191               11202              3011
# 52197               2734                1780               435
#
#        one_star_ratings  number_of_pages      date_published  \
# 0                    92            220.0    January 1st 2007
# 2                    44            320.0    January 1st 2009
# 3                   324            464.0                1997
# 4                  1086            258.0   October 28th 1995
# 5                    63            252.0      March 1st 1966
# ...                 ...              ...                 ...
# 52192               151            447.0  February 26th 2013
# 52193               107            352.0                2007
# 52194               378            312.0                2007
# 52195               744            208.0      April 8th 2014
# 52197               106            240.0     April 24th 2007
#
#                                      publisher  \
# 0      Simon  Schuster Books for Young Readers
# 2                                    Zondervan
# 3                                    Tor Books
# 4                                Gallery Books
# 5                                        Arrow
# ...                                        ...
# 52192                                HQN Books
# 52193                           Minotaur Books
# 52194                         Kensington Trade
# 52195                                 Scribner
# 52197  Simon  Schuster Books for Young Readers
#
#                                          genre_and_votes        isbn  \
# 0                Young Adult 161, Mystery 45, Romance 32  1416950419
# 2        Christian Fiction 174, Christian 81, Fiction 58         NaN
# 3      Thriller 626, Mystery 493, Horror 432, Fiction...  0765354950
# 4      Economics-Finance 1162, Nonfiction 910, Busine...  0671015206
# 5      Romance 550, Historical-Historical Fiction 316...  0099468034
# ...                                                  ...         ...
# 52192  Romance-Paranormal Romance 405, Fantasy-Parano...  0373777434
# 52193  Mystery 198, Fiction 110, Thriller 96, Suspens...  0312365705
# 52194  Romance-Historical Romance 335, Romance 312, H...  075829039X
# 52195  Nonfiction 1307, Short Stories 766, Writing-Es...  147675361X
# 52197            Young Adult 182, Mystery 52, Romance 34  1416918760
#
#               isbn13                                         characters  \
# 0      9781416950417                                                NaN
# 2                NaN                                                NaN
# 3      9780765354952  Aloysius X.L. Pendergast, Margo Green, William...
# 4      9780671015206                                                NaN
# 5      9780099468035                Abigail Wendover, Miles Calverleigh
# ...              ...                                                ...
# 52192  9780373777433                                 Koldo, Nicola Lane
# 52193  9780312365707  Monica Taylor, Annie Taylor, Fiona Pritzle, To...
# 52194  9780758290397                     Gerard Faulkner, Isabel Pelham
# 52195  9781476753614                                                NaN
# 52197  9781416918769                                                NaN
#
#                                                   awards
# 0                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      Independent Publisher Book Award (IPPY) Nomine...
# 5                                                    NaN
# ...                                                  ...
# 52192                                                NaN
# 52193                  Edgar Award for Best Novel (2009)
# 52194                                                NaN
# 52195  Goodreads Choice Award for Nonfiction (2014), ...
# 52197                                                NaN
#
# [15647 rows x 20 columns]

# %%
type(data[data['five_star_ratings'] > 2500])
# Out:
# pandas.DataFrame

# %%
data[data['five_star_ratings'] > 2500]['number_of_pages'].mean()
# Out:
# np.float64(360.23779152171113)

# %%
data[data['five_star_ratings'] > 3500]['number_of_pages'].mean()
# Out:
# np.float64(365.10797158642464)

# %%
data['date_published']
# Out:
# 0         January 1st 2007
# 1        October 29th 2006
# 2         January 1st 2009
# 3                     1997
# 4        October 28th 1995
#                ...
# 52194                 2007
# 52195       April 8th 2014
# 52196                 1961
# 52197      April 24th 2007
# 52198     January 1st 2009
# Name: date_published, Length: 52199, dtype: str

# %%
data[data['date_published'].str.len() == 3]
# Out:
#              id                                              title  \
# 2606    7123161  The Arabian Nights: Tales of 1001 Nights, Volu...
# 3835    1072113  The HarperCollins Study Bible: Fully Revised &...
# 4878      80084                                   Cupid and Psyche
# 5848     731140                       Eusebius: The Church History
# 8272    9699011                                            Organon
# 8753    7495363                        Ø§ÙØ³ÙØ±Ø© Ø§ÙÙØ¨ÙÙØ©
# 10679    199707                Holy Bible: The Greek New Testament
# 12120    400299  Somnium Scipionis: The Dream of Scipio (Studen...
# 12227   6403740                                           ÙØ±Ø¢Ù
# 12256  12406749                                   ÙØ±Ø¢Ù Ú©Ø±ÛÙ
# 13721    896422                       The MeghadÅ«ta of KÄlidÄsa
# 14711    767642                                    The Lotus Sutra
# 15067     25673                                        City of God
# 16514   1618417                              ÙÙØ¬ Ø§ÙØ¨ÙØ§ØºÙ
# 18846     55002                     The Fall of the Roman Republic
# 19312   4371304  Epistles Book II and Epistle to the Pisones (A...
# 20559  10602457                                      Arte poÃ©tica
# 20567   1016881                                  Daphnis and Chloe
# 20979    216537  Theological Tractates/The Consolation of Philo...
# 21101    641936                     The Recognition of ÅakuntalÄ
# 21639    132876                  Satires, Epistles and Ars Poetica
# 22632    279456                        Plutarch's Lives: Volume II
# 23553    415634                         Plutarch's Lives: Volume I
# 24077    766196  Commentary on the Creed of At-Tahawi: Sharh Al...
# 26050   6998403                                   On the Good Life
# 26123    563563  Sefer Yetzirah: The Book of Creation: In Theor...
# 27036   6000913                                  The Diamond Sutra
# 27861    785972                                        The Trinity
# 27863    551367                              Tusculan Disputations
# 27888    561444                                 The Secret History
# 28288   2467557                      The Essential Marcus Aurelius
# 30506    279461  Roman Lives: A Selection of Eight Lives (Aemil...
# 31542    382901                          The Complete KÄma-SÅ«tra
# 33996    493005                               The Nature of Things
# 35610   4881794                    Lettres d'amour: Les HÃ©roÃ¯des
# 37212    208123                       The Tibetan Book of the Dead
# 41888    646462                           Ø§ÙÙØ±Ø¢Ù Ø§ÙÙØ±ÙÙ
# 41896     52357                                            Beowulf
# 42258     12914                                         The Aeneid
# 42478     30659                                        Meditations
# 43229     27037                                        Confessions
# 43899   2498952                              ÙÙÙÙØ© ÙØ¯Ù
# ÙØ©
# 47323     80081                                     The Golden Ass
# 48116     29022                                 The Twelve Caesars
# 48358     24618  The Art of Living: The Classical Manual on Vir...
# 48728     31837                      The Consolation of Philosophy
# 50242     75586  The TÃ¡in: From the Irish Epic TÃ¡in BÃ³ CÃºai...
# 50541    592167                               The Conquest of Gaul
# 51056     26252                                        The Enneads
# 51235   3679100                                     Parallel Lives
#
#                                         series  \
# 2606                                       NaN
# 3835                                       NaN
# 4878                                       NaN
# 5848                                       NaN
# 8272                                       NaN
# 8753                                       NaN
# 10679                                      NaN
# 12120                                      NaN
# 12227                                      NaN
# 12256                                      NaN
# 13721                                      NaN
# 14711                                      NaN
# 15067                                      NaN
# 16514                                      NaN
# 18846                                      NaN
# 19312                                      NaN
# 20559                                      NaN
# 20567                                      NaN
# 20979                                      NaN
# 21101                                      NaN
# 21639                                      NaN
# 22632       (ÎÎ¯Î¿Î¹ Î Î±ÏÎ¬Î»Î»Î·Î»Î¿Î¹ #2)
# 23553       (ÎÎ¯Î¿Î¹ Î Î±ÏÎ¬Î»Î»Î·Î»Î¿Î¹ #1)
# 24077                                      NaN
# 26050                                      NaN
# 26123                                      NaN
# 27036                                      NaN
# 27861                                      NaN
# 27863                                      NaN
# 27888                                      NaN
# 28288                                      NaN
# 30506                                      NaN
# 31542                                      NaN
# 33996                                      NaN
# 35610                                      NaN
# 37212                                      NaN
# 41888                                      NaN
# 41896                                      NaN
# 42258                                      NaN
# 42478                                      NaN
# 43229                                      NaN
# 43899                                      NaN
# 47323                                      NaN
# 48116  (The Lives of the Twelve Caesars #1-12)
# 48358                                      NaN
# 48728                                      NaN
# 50242                                      NaN
# 50541                                      NaN
# 51056                                      NaN
# 51235                                      NaN
#
#                                                   author  rating_count  \
# 2606   testing testing, Malcolm C. Lyons, Ursula Lyon...          2942
# 3835   Anonymous, Wayne A. Meeks, Harold W. Attridge,...           784
# 4878                        Apuleius, Edward John Kenney          2310
# 5848                                       Paul L. Maier          3553
# 8272                            Aristotle, Giorgio Colli           210
# 8753              Ø§Ø¨Ù ÙØ´Ø§Ù
# , Ù
# ØµØ·ÙÙ Ø§ÙØ³ÙØ§          1078
# 10679  Anonymous, Barbara Aland, Kurt Aland, B.M. Met...          1806
# 12120              Marcus Tullius Cicero, Gilbert Lawall           111
# 12227  Anonymous, Ø­Ø³ÛÙ Ù
# Ø­ÛâØ§ÙØ¯ÛÙ Ø§ÙÙ...         56834
# 12256      Anonymous, Ø¹ÙÛ Ù
# ÙØ³ÙÛ Ú¯Ø±Ù
# Ø§Ø±ÙØ¯Û         56836
# 13721                              KÄlidÄsa, M.R. Kale           297
# 14711                           Anonymous, Burton Watson          1532
# 15067                Augustine of Hippo, Henry Bettenson         10124
# 16514  Ø¹ÙÙ Ø¨Ù Ø£Ø¨Ù Ø·Ø§ÙØ¨, Ø§ÙØ´Ø±ÙÙ Ø§Ù...          1759
# 18846                 Plutarch, Rex Warner, Robin Seager          3632
# 19312                                             Horace            41
# 20559               Horace, HorÃ¡cio, Juan Gil Fernandez           327
# 20567                                Longus, Paul Turner          2794
# 20979     Boethius, H.F. Stewart, E.K. Rand, S.J. Tester           283
# 21101                           KÄlidÄsa, W.J. Johnson          1205
# 21639                            Horace, H.R. Fairclough           746
# 22632  Plutarch, John Dryden, Arthur Hugh Clough, Jam...          2865
# 23553  Plutarch, John Dryden, Arthur Hugh Clough, Jam...          5237
# 24077  Ibn Abil-'Izz al-Hanafee, Muhammad Abdul-Haqq ...           726
# 26050               Marcus Tullius Cicero, Michael Grant          1825
# 26123                            Anonymous, Aryeh Kaplan          1004
# 27036                                          Anonymous           810
# 27861   Augustine of Hippo, Edmund Hill, John E. Rotelle           884
# 27863                              Marcus Tullius Cicero           263
# 27888                                          Procopius          2373
# 28288      Marcus Aurelius, John Piazza, Jacob Needleman           796
# 30506      Plutarch, Robin Waterfield, Philip A. Stadter           516
# 31542  Mallanaga VÄtsyÄyana, Alain DaniÃ©lou, A.N.D...          5334
# 33996         Lucretius, A.E. Stallings, Richard Jenkyns         11149
# 35610  Ovid, Jean-Pierre NÃ©raudau, ThÃ©ophile Baudem...          2428
# 37212  Padmasambhava, Karma-glin-pa, Gyurme Dorje, Gr...          7578
# 41888                                          Anonymous         56700
# 41896                             Unknown, Seamus Heaney        229783
# 42258                          Virgil, Robert Fitzgerald        104461
# 42478  Marcus Aurelius, Martin Hammond, Albert Wittst...        111323
# 43229  Augustine of Hippo, Henry Chadwick, Albert Coo...         44436
# 43899  Ø¹Ø¨Ø¯ Ø§ÙÙÙ Ø¨Ù Ø§ÙÙ
# ÙÙØ¹, Ø¹Ø¨Ø¯ Ø§Ù...          6455
# 47323         Apuleius, Jack Lindsay, Claudio Annaratone         11769
# 48116            Suetonius, Michael Grant, Robert Graves         15434
# 48358                           Epictetus, Sharon Lebell         13483
# 48728                             Boethius, Victor Watts         10994
# 50242       Anonymous, Thomas Kinsella, Louis Le Brocquy          3533
# 50541  Gaius Julius Caesar, S.A. Handford, Jane F. Ga...          8534
# 51056         Plotinus, Stephen MacKenna, John M. Dillon          2715
# 51235          Plutarch, Arthur Hugh Clough, John Dryden          1430
#
#        review_count  average_rating  five_star_ratings  four_star_ratings  \
# 2606            108            4.05               1156               1029
# 3835             48            4.37                457                208
# 4878            120            4.11                892                888
# 5848            223            4.00               1309               1199
# 8272             18            4.00                 81                 63
# 8753             54            4.53                755                198
# 10679            69            4.54               1267                335
# 12120             9            4.02                 38                 42
# 12227          3053            4.35              41251               4562
# 12256          3053            4.35              41252               4562
# 13721            24            4.16                132                 98
# 14711            52            4.23                762                464
# 15067           470            3.92               3757               3113
# 16514           188            4.56               1343                223
# 18846            74            4.09               1424               1288
# 19312             0            3.88                 15                 11
# 20559            27            3.61                 63                116
# 20567           209            3.77                714               1017
# 20979            26            4.23                139                 86
# 21101            90            3.84                354                435
# 21639            22            4.08                312                235
# 22632            50            4.17               1309                901
# 23553           151            4.09               2144               1779
# 24077            73            4.43                465                154
# 26050            78            4.01                651                661
# 26123            44            4.32                571                251
# 27036            48            4.37                476                201
# 27861            56            4.34                483                256
# 27863            13            4.00                 92                 95
# 27888           179            3.86                736                798
# 28288            58            4.37                447                229
# 30506            23            4.08                183                211
# 31542           395            3.49               1287               1420
# 33996           519            3.98               4325               3485
# 35610            86            4.13               1026                817
# 37212           136            4.22               3749               2221
# 41888          3053            4.35              41141               4554
# 41896          6403            3.45              48935              65009
# 42258          2616            3.84              31796              35424
# 42478          5773            4.23              55996              33444
# 43229          2269            3.93              16856              13763
# 43899           629            4.10               2729               2127
# 47323           709            3.88               3628               4241
# 48116           589            4.06               5733               5798
# 48358          1157            4.24               6387               4540
# 48728           684            3.98               4061               3677
# 50242           250            3.97               1201               1299
# 50541           408            4.00               2978               3145
# 51056            54            4.05               1186                759
# 51235            68            4.12                613                478
#
#        three_star_ratings  two_star_ratings  one_star_ratings  \
# 2606                  565               131                61
# 3835                   83                21                15
# 4878                  444                73                13
# 5848                  828               165                52
# 8272                   53                12                 1
# 8753                   81                24                20
# 10679                 146                35                23
# 12120                  26                 5                 0
# 12227                4582              2582              3857
# 12256                4582              2582              3858
# 13721                  53                10                 4
# 14711                 225                57                24
# 15067                2257               712               285
# 16514                  91                42                60
# 18846                 775               118                27
# 19312                  10                 5                 0
# 20559                 110                33                 5
# 20567                 808               205                50
# 20979                  45                10                 3
# 21101                 311                82                23
# 21639                 155                34                10
# 22632                 512               118                25
# 23553                1030               217                67
# 24077                  73                19                15
# 26050                 408                83                22
# 26123                 132                37                13
# 27036                 100                25                 8
# 27861                 115                20                10
# 27863                  62                11                 3
# 27888                 640               166                33
# 28288                  96                18                 6
# 30506                 101                20                 1
# 31542                1586               684               357
# 33996                2365               723               251
# 35610                 476                86                23
# 37212                1255               254                99
# 41888                4572              2577              3856
# 41896               70354             30935             14550
# 42258               27920              7447              1874
# 42478               15787              4181              1915
# 43229                9235              3079              1503
# 43899                1196               291               112
# 47323                2906               811               183
# 48116                3131               577               195
# 48358                2019               427               110
# 48728                2414               657               185
# 50242                 798               179                56
# 50541                1905               420                86
# 51056                 550               159                61
# 51235                 258                63                18
#
#        number_of_pages date_published  \
# 2606             982.0            800
# 3835            2208.0            393
# 4878             256.0            170
# 5848             416.0            324
# 8272            1066.0            -40
# 8753            1109.0            833
# 10679            918.0            382
# 12120             96.0            -51
# 12227            800.0            650
# 12256              NaN            650
# 13721            208.0            400
# 14711            390.0            150
# 15067           1186.0            426
# 16514            596.0            800
# 18846            414.0            100
# 19312              NaN            -20
# 20559            168.0            -19
# 20567            128.0            150
# 20979            457.0            524
# 21101            192.0            400
# 21639            544.0            -10
# 22632            706.0            100
# 23553            766.0            100
# 24077            538.0            933
# 26050            415.0            -46
# 26123            398.0            200
# 27036              NaN            868
# 27861            472.0            416
# 27863            624.0            -45
# 27888            208.0            550
# 28288            111.0            180
# 30506            608.0            100
# 31542            564.0            300
# 33996            304.0            -55
# 35610            332.0            -16
# 37212            535.0            800
# 41888            604.0            650
# 41896            245.0            975
# 42258            442.0            -19
# 42478            303.0            180
# 43229            341.0            400
# 43899            366.0            756
# 47323            256.0            170
# 48116            363.0            121
# 48358            128.0            125
# 48728            192.0            524
# 50242            282.0            900
# 50541            269.0            -50
# 51056            688.0            250
# 51235           1309.0            100
#
#                                                publisher  \
# 2606                                    Penguin Classics
# 3835                                           HarperOne
# 4878                          Cambridge University Press
# 5848                      Kregel Academic & Professional
# 8272                                             Adelphi
# 8753                               Ø¯Ø§Ø± Ø§ÙÙ
# Ø¹Ø±ÙØ©
# 10679                                         Hendrickso
# 12120                  Addison Wesley Publishing Company
# 12227                                                NaN
# 12256                                                NaN
# 13721                                   South Asia Books
# 14711                          Columbia University Press
# 15067                                  Penguin Books Ltd
# 16514  Ø´Ø±Ú©Øª Ø§ÙØªØ´Ø§Ø±Ø§Øª Ø¹ÙÙ
# Û Ù ÙØ±ÙÙ...
# 18846                                   Penguin Classics
# 19312                                         InquÃ©rito
# 20559                                        Dykinson Sl
# 20567                                   Penguin Classics
# 20979                           Harvard University Press
# 21101                            Oxford University Press
# 21639                             Loeb Classical Library
# 22632                                     Modern Library
# 23553                                     Modern Library
# 24077                                    Imam University
# 26050                                  The Folio Society
# 26123                                   Red Wheel/Weiser
# 27036                                                NaN
# 27861                                     New City Press
# 27863                           Harvard University Press
# 27888                                   Penguin Classics
# 28288                                     Tarcherperigee
# 30506                       Oxford University Press, USA
# 31542                                  Park Street Press
# 33996                                  Penguin Books Ltd
# 35610                                          Gallimard
# 37212                                   Penguin Classics
# 41888                                                NaN
# 41896                              W.W. Norton & Company
# 42258                                            Vintage
# 42478                                      Penguin Books
# 43229                            Oxford University Press
# 43899                                Ø¯Ø§Ø± Ø§ÙØ´Ø±ÙÙ
# 47323                           Indiana University Press
# 48116                                   Penguin Classics
# 48358                                          HarperOne
# 48728                                   Penguin Classics
# 50242                            Oxford University Press
# 50541                                   Penguin Classics
# 51056                                   Penguin Classics
# 51235                                     Modern Library
#
#                                          genre_and_votes        isbn  \
# 2606   Classics 147, Fiction 73, Fantasy 56, Short St...  0140449388
# 3835   Religion 51, Religion-Christianity 17, Christi...  0060786841
# 4878   Classics 90, Fantasy-Mythology 28, Fiction 22,...  0521278139
# 5848   History 376, Religion 128, Church-Church Histo...  0825433282
# 8272   Philosophy 61, Classics 6, Philosophy-Logic 5,...  884591755X
# 8753          Religion 22, Religion-Islam 16, History 12         NaN
# 10679    Reference 76, Religion 48, Religion-Theology 29  1598561715
# 12120                            Philosophy 5, History 3  0582367514
# 12227  Religion 1301, Religion-Islam 473, Nonfiction ...         NaN
# 12256  Religion 1301, Religion-Islam 473, Nonfiction ...         NaN
# 13721  Poetry 24, Cultural-India 5, Classics 4, Liter...  8120804201
# 14711  Religion-Buddhism 89, Religion 44, Philosophy ...  0231081618
# 15067  Philosophy 563, Religion-Theology 435, Religio...  0140448942
# 16514  Religion 44, Religion-Islam 24, Nonfiction 13,...         NaN
# 18846  History 258, Classics 128, Nonfiction 88, Biog...  0140449345
# 19312   Classics 3, Poetry 2, Academic-Grad School 1user  0816111921
# 20559  Poetry 23, Classics 20, Nonfiction 13, Philoso...  849849883X
# 20567  Classics 244, Fiction 80, Romance 65, Fantasy-...         NaN
# 20979     Philosophy 34, Religion 7, Religion-Theology 5  0674990838
# 21101  Plays 80, Classics 59, Cultural-India 40, Dram...  019283911X
# 21639  Poetry 51, Classics 30, Philosophy 10, Nonfict...  0674992148
# 22632  History 205, Classics 127, Biography 86, Nonfi...  0375756779
# 23553  History 432, Classics 249, Biography 164, Nonf...  0375756760
# 24077  Religion-Islam 37, Religion 18, Nonfiction 6, ...  9960043231
# 26050  Philosophy 309, Classics 92, Nonfiction 46, Hi...         NaN
# 26123  Religion 30, Religion-Judaism 21, Occult 20, S...  0877288550
# 27036  Religion-Buddhism 72, Religion 35, Philosophy ...         NaN
# 27861  Religion-Theology 116, Philosophy 44, Religion...  0911782966
# 27863  Philosophy 41, Classics 9, Nonfiction 5, Histo...  0674991567
# 27888  History 303, Classics 72, Nonfiction 71, Histo...  0140441824
# 28288  Philosophy 76, Classics 15, History 15, Nonfic...  1585426172
# 30506  History 63, Classics 33, Nonfiction 29, Biogra...  019282502X
# 31542  Nonfiction 179, Classics 109, Adult Fiction-Er...  0892814926
# 33996  Philosophy 898, Poetry 386, Classics 381, Nonf...  0140447962
# 35610  Poetry 167, Classics 140, Fantasy-Mythology 48...  2070401537
# 37212  Philosophy 140, Religion 131, Religion-Buddhis...  0143104942
# 41888  Religion 1301, Religion-Islam 473, Nonfiction ...         NaN
# 41896  Classics 7597, Poetry 4144, Fiction 2213, Fant...  0393320979
# 42258  Classics 4347, Poetry 2125, Fiction 1031, Fant...  0679729526
# 42478  Philosophy 6807, Nonfiction 2056, Classics 201...  0140449337
# 43229  Philosophy 1407, Classics 1094, Religion 992, ...  0192833723
# 43899  Fiction 50, Literature 40, Classics 38, Short ...         NaN
# 47323  Classics 554, Fiction 307, Fantasy-Mythology 1...  0253200369
# 48116  History 1280, Classics 523, Nonfiction 385, Bi...  0140449213
# 48358  Philosophy 1558, Nonfiction 349, Classics 229,...  006251346X
# 48728  Philosophy 1356, Classics 302, Nonfiction 184,...  0140447806
# 50242  Fantasy-Mythology 156, Classics 133, Cultural-...  0192803735
# 50541  History 763, Classics 282, Nonfiction 202, His...  0140444335
# 51056  Philosophy 367, Classics 56, Nonfiction 27, Re...  014044520X
# 51235  History 167, Classics 104, Biography 75, Nonfi...  0394604075
#
#               isbn13                                         characters  \
# 2606   9780140449389                             Shahryar, Scheherazade
# 3835   9780060786847                                                NaN
# 4878   9780521278133                                                NaN
# 5848   9780825433283  IrenÃ¦us, Heraclas, Dionysius the Areopagite, ...
# 8272   9788845917554                                                NaN
# 8753             NaN                                                NaN
# 10679  9781598561715                                                NaN
# 12120  9780582367517                                                NaN
# 12227            NaN  Moses (Bible), Jesus, Mary (mother of Jesus), ...
# 12256            NaN  Moses (Bible), Jesus, Mary (mother of Jesus), ...
# 13721  9788120804203                                                NaN
# 14711  9780231081610                                                NaN
# 15067  9780140448948                                                NaN
# 16514            NaN                                                NaN
# 18846  9780140449341  Gnaeus Pompeius Magnus, Gaius Marius, Lucius C...
# 19312            NaN                                                NaN
# 20559  9788498498837                                                NaN
# 20567            NaN                                     Daphnis, Chloe
# 20979  9780674990838                                                NaN
# 21101  9780192839114                                                NaN
# 21639  9780674992146                                                NaN
# 22632  9780375756771                                                NaN
# 23553  9780375756764                                                NaN
# 24077  9789960043234                                                NaN
# 26050            NaN                                                NaN
# 26123  9780877288558                                                NaN
# 27036            NaN                                                NaN
# 27861  9780911782967                                                NaN
# 27863  9780674991569                                                NaN
# 27888  9780140441826                                                NaN
# 28288  9781585426171                                                NaN
# 30506  9780192825025                                                NaN
# 31542  9780892814923                                                NaN
# 33996  9780140447965                                                NaN
# 35610  9782070401536                                             Aeneas
# 37212  9780143104940                                      Padmasambhava
# 41888            NaN  Moses (Bible), Abraham (Bible), Adam (Bible), ...
# 41896  9780393320978  Beowulf, Grendel, Onela, Unferth, Breca, Wigla...
# 42258  9780679729525  Venus (Goddess), Jupiter (God), Aeneas, Juno, ...
# 42478  9780140449334                                     Antoninus Pius
# 43229  9780192833723                        Augustine of Hippo, Ambrose
# 43899            NaN     Ø¨ÙØ¯Ø¨Ø§, Ø¯Ø¨Ø´ÙÙÙ , ÙÙÙÙØ©, Ø¯Ù ÙØ©
# 47323  9780253200365  Cupid, Psyche (mythology), Venus (Goddess), Lu...
# 48116  9780140449211  Nero (emperor), Caligula, Lucius Livius Ocella...
# 48358  9780062513465                                                NaN
# 48728  9780140447804                                           Eurydice
# 50242  9780192803733  Ailill mac MÃ¡ta, Amergin mac Eccit, Bricriu, ...
# 50541  9780140444339                       Vercingetorix, Julius Caesar
# 51056  9780140445206                                                NaN
# 51235  9780394604077                                                NaN
#
#                                                   awards
# 2606                                                 NaN
# 3835                                                 NaN
# 4878                                                 NaN
# 5848                                                 NaN
# 8272                                                 NaN
# 8753                                                 NaN
# 10679                                                NaN
# 12120                                                NaN
# 12227                                                NaN
# 12256                                                NaN
# 13721                                                NaN
# 14711                                                NaN
# 15067                                                NaN
# 16514  Ú©ØªØ§Ø¨ Ø³Ø§Ù Ø¬Ù ÙÙØ±Û Ø§Ø³ÙØ§Ù Û Ø§Û...
# 18846                                                NaN
# 19312                                                NaN
# 20559                                                NaN
# 20567                                                NaN
# 20979                                                NaN
# 21101                                                NaN
# 21639                                                NaN
# 22632                                                NaN
# 23553                                                NaN
# 24077                                                NaN
# 26050                                                NaN
# 26123                                                NaN
# 27036                                                NaN
# 27861                                                NaN
# 27863                                                NaN
# 27888                                                NaN
# 28288                                                NaN
# 30506                                                NaN
# 31542                                                NaN
# 33996  National Book Award Finalist for Translation (...
# 35610                                                NaN
# 37212                                                NaN
# 41888                                                NaN
# 41896                                                NaN
# 42258         National Book Award for Translation (1973)
# 42478                                                NaN
# 43229                                                NaN
# 43899                                                NaN
# 47323                   Mikael Agricola -palkinto (1958)
# 48116                                                NaN
# 48358                                                NaN
# 48728                                                NaN
# 50242                                                NaN
# 50541                                                NaN
# 51056                                                NaN
# 51235                                                NaN

# %%
len(data[data['date_published'].str.len() == 3])
# Out:
# 50

# %%
df = data[data['date_published'].str.len() > 3]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 51279 entries, 0 to 52198
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  51279 non-null  int64
#  1   title               51279 non-null  str
#  2   series              23051 non-null  str
#  3   author              51279 non-null  str
#  4   rating_count        51279 non-null  int64
#  5   review_count        51279 non-null  int64
#  6   average_rating      51279 non-null  float64
#  7   five_star_ratings   51279 non-null  int64
#  8   four_star_ratings   51279 non-null  int64
#  9   three_star_ratings  51279 non-null  int64
#  10  two_star_ratings    51279 non-null  int64
#  11  one_star_ratings    51279 non-null  int64
#  12  number_of_pages     49615 non-null  float64
#  13  date_published      51279 non-null  str
#  14  publisher           48330 non-null  str
#  15  genre_and_votes     48647 non-null  str
#  16  isbn                39983 non-null  str
#  17  isbn13              39212 non-null  str
#  18  characters          13634 non-null  str
#  19  awards              10601 non-null  str
# dtypes: float64(2), int64(8), str(10)
# memory usage: 8.2 MB

# %%
type(df['date_published'])
# Out:
# pandas.Series

# %%
df['date_published']
# Out:
# 0         January 1st 2007
# 1        October 29th 2006
# 2         January 1st 2009
# 3                     1997
# 4        October 28th 1995
#                ...
# 52194                 2007
# 52195       April 8th 2014
# 52196                 1961
# 52197      April 24th 2007
# 52198     January 1st 2009
# Name: date_published, Length: 51279, dtype: str

# %%
df['date_published'].str.extract(r'(\d{4})')
# Out:
#           0
# 0      2007
# 1      2006
# 2      2009
# 3      1997
# 4      1995
# ...     ...
# 52194  2007
# 52195  2014
# 52196  1961
# 52197  2007
# 52198  2009
#
# [51279 rows x 1 columns]

# %% [markdown]
# > Хороший интерактивный ресурс для отладки регулярных выражений: [Regex 101](https://regex101.com/).

# %%
df['year_published'] = df['date_published'].str.extract(r'(\d{4})')

# %%
df['year_published']
# Out:
# 0        2007
# 1        2006
# 2        2009
# 3        1997
# 4        1995
#          ...
# 52194    2007
# 52195    2014
# 52196    1961
# 52197    2007
# 52198    2009
# Name: year_published, Length: 51279, dtype: str

# %%
type(df['date_published'].str.extract(r'(\d{4})'))
# Out:
# pandas.DataFrame

# %%
type(df['year_published'])
# Out:
# pandas.Series

# %%
# 1D numpy массив
df['year_published'] = df['date_published'].str.extract(r'(\d{4})').to_numpy().flatten()

# %%
df['year_published']
# Out:
# 0        2007
# 1        2006
# 2        2009
# 3        1997
# 4        1995
#          ...
# 52194    2007
# 52195    2014
# 52196    1961
# 52197    2007
# 52198    2009
# Name: year_published, Length: 51279, dtype: str

# %%
df['year_published'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 52194    False
# 52195    False
# 52196    False
# 52197    False
# 52198    False
# Name: year_published, Length: 51279, dtype: bool

# %%
df[df['year_published'].isna()]
# Out:
#              id                                      title  \
# 163      901111                Tanakh: The Holy Scriptures
# 255      534289             The I Ching or Book of Changes
# 475    18008226                  Nathaniel's 1st Adventure
# 512    23277468  World Peace: The Voice of a Mountain Bird
# 736       27297                               The Analects
# ...         ...                                        ...
# 49659    159964                             The Dhammapada
# 49706    380609                                The Bacchae
# 49746   4934651                            Fe Fi FOE Comes
# 49888    821535         The Torah: The Five Books of Moses
# 52138    168487                     The Persian Expedition
#
#                      series  \
# 163                     NaN
# 255                     NaN
# 475    (Cosmic Aviators #1)
# 512                     NaN
# 736                     NaN
# ...                     ...
# 49659                   NaN
# 49706                   NaN
# 49746                   NaN
# 49888                   NaN
# 52138                   NaN
#
#                                                   author  rating_count  \
# 163                Anonymous, Jewish Publication Society          2736
# 255    Anonymous, Richard Wilhelm, Cary F. Baynes, C....         17694
# 475                                       G.E.F. Neilson            42
# 512                                 Amit Ray, Banani Ray           107
# 736                                  Confucius, D.C. Lau         17045
# ...                                                  ...           ...
# 49659        Anonymous, Ananda Maitreya, Thich Nhat Hanh         22062
# 49706       Euripides, Kenneth McLeish, Frederic Raphael         13823
# 49746                                 William C. Samples            19
# 49888                       Anonymous, Harry M. Orlinsky          1587
# 52138  Xenophon, Rex Warner, H.G. Dakyns, George Cawk...          6246
#
#        review_count  average_rating  five_star_ratings  four_star_ratings  \
# 163             100            4.38               1684                598
# 255             352            4.19               8676               4991
# 475              22            4.33                 28                  5
# 512               9            4.62                 79                 21
# 736             660            3.83               5329               5555
# ...             ...             ...                ...                ...
# 49659           887            4.28              11751               6167
# 49706           634            3.89               4356               4876
# 49746             8            4.37                 11                  5
# 49888           100            4.18                895                308
# 52138           334            4.09               2466               2223
#
#        three_star_ratings  two_star_ratings  one_star_ratings  \
# 163                   319                85                50
# 255                  3076               698               253
# 475                     6                 1                 2
# 512                     4                 0                 3
# 736                  4470              1299               392
# ...                   ...               ...               ...
# 49659                3136               682               326
# 49706                3504               858               229
# 49746                   2                 1                 0
# 49888                 224                93                67
# 52138                1265               230                62
#
#        number_of_pages     date_published                       publisher  \
# 163             1624.0               -450  The Jewish Publication Society
# 255              740.0               -850      Princeton University Press
# 475              332.0        June 14th 1                  Buzzword Press
# 512              164.0  September 9th 214          Inner Light Publishers
# 736              249.0               -429               Penguin Books Ltd
# ...                ...                ...                             ...
# 49659            114.0  January 30th -400                  Parallax Press
# 49706             96.0               -405                 Nick Hern Books
# 49746            869.0       May 25th 201              Vel North Editions
# 49888            394.0               -400  The Jewish Publication Society
# 52138            375.0               -390                Penguin Classics
#
#                                          genre_and_votes        isbn  \
# 163    Religion 129, Religion-Judaism 72, Literature-...  0827603665
# 255    Philosophy 420, Religion 164, Nonfiction 154, ...  069109750X
# 475    Childrens 1user, Childrens-Middle Grade 1user,...         NaN
# 512    Inspirational 14, Spirituality 9, Self Help 8,...         NaN
# 736    Philosophy 1445, Classics 469, Nonfiction 378,...  0140443487
# ...                                                  ...         ...
# 49659  Religion-Buddhism 571, Religion 519, Philosoph...  0938077872
# 49706  Plays 669, Classics 639, Drama 262, Fantasy-My...  1854594117
# 49746                                       Philosophy 2  098006810X
# 49888  Religion 128, Religion-Judaism 30, Philosophy ...  0827600151
# 52138  History 509, Classics 212, Nonfiction 137, War...  0140440070
#
#               isbn13                                         characters  \
# 163    9780827603660                                                NaN
# 255    9780691097503                                                NaN
# 475              NaN                                                NaN
# 512              NaN                                                NaN
# 736    9780140443486                                                NaN
# ...              ...                                                ...
# 49659  9780938077879                                                NaN
# 49706  9781854594112  Dionysus (mythology), Pentheus, Cadmus (mythol...
# 49746  9780980068108                                                NaN
# 49888  9780827600157                                                NaN
# 52138  9780140440072                                                NaN
#
#                              awards year_published
# 163                             NaN            NaN
# 255                             NaN            NaN
# 475                             NaN            NaN
# 512                             NaN            NaN
# 736    J. A. Hollon palkinto (2015)            NaN
# ...                             ...            ...
# 49659                           NaN            NaN
# 49706                           NaN            NaN
# 49746                           NaN            NaN
# 49888                           NaN            NaN
# 52138                           NaN            NaN
#
# [89 rows x 21 columns]

# %%
df[df['year_published'].isna()].index
# Out:
# Index([  163,   255,   475,   512,   736,  2692,  3397,  4726,  5335,  5719,
#         5973,  6115,  6462,  6909,  7208,  7508,  8340,  8826,  9226, 10806,
#        12068, 12484, 12549, 12764, 14486, 14565, 15712, 16012, 16038, 16634,
#        17160, 17896, 19630, 21406, 21473, 25820, 26070, 26879, 28973, 31663,
#        32484, 32791, 33071, 34517, 34624, 35620, 36093, 36277, 36449, 37004,
#        37078, 37432, 38494, 41070, 41572, 41751, 41918, 42036, 42154, 42194,
#        42319, 42447, 42457, 42517, 42812, 43039, 43055, 43095, 43779, 43793,
#        43883, 44323, 44734, 45027, 45488, 45545, 45676, 46013, 46480, 47804,
#        48251, 48630, 49272, 49323, 49659, 49706, 49746, 49888, 52138],
#       dtype='int64')

# %%
df = df.drop(df[df['year_published'].isna()].index)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 51190 entries, 0 to 52198
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  51190 non-null  int64
#  1   title               51190 non-null  str
#  2   series              23034 non-null  str
#  3   author              51190 non-null  str
#  4   rating_count        51190 non-null  int64
#  5   review_count        51190 non-null  int64
#  6   average_rating      51190 non-null  float64
#  7   five_star_ratings   51190 non-null  int64
#  8   four_star_ratings   51190 non-null  int64
#  9   three_star_ratings  51190 non-null  int64
#  10  two_star_ratings    51190 non-null  int64
#  11  one_star_ratings    51190 non-null  int64
#  12  number_of_pages     49530 non-null  float64
#  13  date_published      51190 non-null  str
#  14  publisher           48246 non-null  str
#  15  genre_and_votes     48562 non-null  str
#  16  isbn                39911 non-null  str
#  17  isbn13              39140 non-null  str
#  18  characters          13604 non-null  str
#  19  awards              10593 non-null  str
#  20  year_published      51190 non-null  str
# dtypes: float64(2), int64(8), str(11)
# memory usage: 8.6 MB

# %%
df['year_published'] = df['year_published'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 51190 entries, 0 to 52198
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  51190 non-null  int64
#  1   title               51190 non-null  str
#  2   series              23034 non-null  str
#  3   author              51190 non-null  str
#  4   rating_count        51190 non-null  int64
#  5   review_count        51190 non-null  int64
#  6   average_rating      51190 non-null  float64
#  7   five_star_ratings   51190 non-null  int64
#  8   four_star_ratings   51190 non-null  int64
#  9   three_star_ratings  51190 non-null  int64
#  10  two_star_ratings    51190 non-null  int64
#  11  one_star_ratings    51190 non-null  int64
#  12  number_of_pages     49530 non-null  float64
#  13  date_published      51190 non-null  str
#  14  publisher           48246 non-null  str
#  15  genre_and_votes     48562 non-null  str
#  16  isbn                39911 non-null  str
#  17  isbn13              39140 non-null  str
#  18  characters          13604 non-null  str
#  19  awards              10593 non-null  str
#  20  year_published      51190 non-null  int64
# dtypes: float64(2), int64(9), str(10)
# memory usage: 8.6 MB

# %% [markdown]
# #### Группировка данных
#
# [GroupBy](https://pandas.pydata.org/docs/reference/groupby.html).

# %%
dfgby = df.groupby('year_published')

# %%
type(dfgby)
# Out:
# pandas.api.typing.DataFrameGroupBy

# %%
len(dfgby)
# Out:
# 449

# %%
for year, sub_df in dfgby:
    if year == 2009:
        print(sub_df)
# Out:
#             id                                              title  \
# 2      6050894                                           Take Two
# 35     6419887  The Boy Who Harnessed the Wind: Creating Curre...
# 58     5498077                                  Code of the Clans
# 66     6556261                                      Hell's Heroes
# 97     3942622                                The Immortal Hunter
# ...        ...                                                ...
# 52079  4010795                                           Take One
# 52088  7145565                                   Flaskepost fra P
# 52127  6566616                                    Crocodile Tears
# 52153  4067103                                    Ransom My Heart
# 52198  6922622                      Going Rogue: An American Life
#
#                            series                                     author  \
# 2             (Above the Line #2)                            Karen Kingsbury
# 35                            NaN            William Kamkwamba, Bryan Mealer
# 58     (Warriors: Field Guide #3)              Erin Hunter, Wayne McLoughlin
# 66             (The Demonata #10)               Darren Shan, Richard PodanÃ½
# 97                 (Argeneau #11)                               Lynsay Sands
# ...                           ...                                        ...
# 52079         (Above the Line #1)                            Karen Kingsbury
# 52088             (Afdeling Q #3)                          Jussi Adler-Olsen
# 52127             (Alex Rider #8)                           Anthony Horowitz
# 52153      (The Princess Diaries)                 Meg Cabot, Mia Thermopolis
# 52198                         NaN  Sarah Palin, Lynn Vincent, Dewey Whetsell
#
#        rating_count  review_count  average_rating  five_star_ratings  \
# 2              6288           218            4.23               3000
# 35            20578          3332            4.11               7843
# 58             5973           113            4.20               3072
# 66             7852           280            4.28               4245
# 97            13973           357            4.22               6412
# ...             ...           ...             ...                ...
# 52079          7869           338            4.20               3652
# 52088         28164          1734            4.02               9448
# 52127         28521           870            4.19              12722
# 52153          7210           515            3.74               2207
# 52198         11359          1246            3.28               2379
#
#        four_star_ratings  three_star_ratings  two_star_ratings  \
# 2                   2020                1041               183
# 35                  8366                3461               653
# 58                  1471                1065               305
# 66                  2063                1138               294
# 97                  4696                2437               366
# ...                  ...                 ...               ...
# 52079               2536                1346               241
# 52088              12220                4820              1019
# 52127               9767                4879               919
# 52153               2169                1848               700
# 52198               3085                2921              1262
#
#        one_star_ratings  number_of_pages       date_published  \
# 2                    44            320.0     January 1st 2009
# 35                  255            270.0  September 29th 2009
# 58                   60            156.0        June 1st 2009
# 66                  112            256.0     January 1st 2009
# 97                   62            360.0      March 31st 2009
# ...                 ...              ...                  ...
# 52079                94            352.0    January 28th 2009
# 52088               657            494.0                 2009
# 52127               234            385.0    November 1st 2009
# 52153               286            396.0     January 6th 2009
# 52198              1712            413.0     January 1st 2009
#
#                        publisher  \
# 2                      Zondervan
# 35                William Morrow
# 58                 HarperCollins
# 66                 Harpercollins
# 97                          Avon
# ...                          ...
# 52079                  Zondervan
# 52088          Politikens forlag
# 52127             Philomel Books
# 52153  William Morrow Paperbacks
# 52198                     Harper
#
#                                          genre_and_votes        isbn  \
# 2        Christian Fiction 174, Christian 81, Fiction 58         NaN
# 35     Nonfiction 732, Cultural-Africa 289, Autobiogr...  0061730327
# 58                                Fantasy 84, Animals 45  0061660094
# 66     Horror 167, Fantasy 138, Young Adult 102, Fict...  0007260350
# 97     Romance-Paranormal Romance 326, Paranormal-Vam...  0061474304
# ...                                                  ...         ...
# 52079   Christian Fiction 209, Christian 111, Fiction 81  0310266165
# 52088  Mystery 368, Mystery-Crime 303, Thriller 245, ...  8756787650
# 52127  Young Adult 301, Adventure 170, Fiction 133, A...  0399250565
# 52153  Romance 303, Historical-Historical Fiction 161...  006170007X
# 52198  Biography 176, Nonfiction 171, Politics 165, B...  0061939897
#
#               isbn13                                         characters  \
# 2                NaN                                                NaN
# 35     9780061730320                                                NaN
# 58     9780061660092                                                NaN
# 66     9780007260355                                                NaN
# 97     9780061474309      Decker Argeneau Pimms, Danielle 'Dani' McGill
# ...              ...                                                ...
# 52079  9780310266167                                                NaN
# 52088  9788756787659                                        Carl MÃ¸rck
# 52127  9780399250569  Alex Rider, Alan Blunt, Jack Starbright, Smith...
# 52153  9780061700071                    Finnula Crais, Hugo Fitzstephen
# 52198  9780061939891  Joe Biden, Sarah Palin, Glenn Beck, Katie Cour...
#
#                                                   awards  year_published
# 2                                                    NaN            2009
# 35     ALA Alex Award (2010), Corine Internationaler ...            2009
# 58                                                   NaN            2009
# 66                                                   NaN            2009
# 97                                                   NaN            2009
# ...                                                  ...             ...
# 52079                                                NaN            2009
# 52088  Barry Award Nominee for Best Novel (2014), Gla...            2009
# 52127                                                NaN            2009
# 52153                                                NaN            2009
# 52198                                                NaN            2009
#
# [2040 rows x 21 columns]

# %%
dfgby['three_star_ratings'].mean()
# Out:
# year_published
# 1000      98.000000
# 1001      58.000000
# 1002    1241.000000
# 1008    2858.500000
# 1010     343.000000
#            ...
# 2017    2486.990654
# 2018    2477.068063
# 2019    1557.872564
# 2020     711.016393
# 2021       2.600000
# Name: three_star_ratings, Length: 449, dtype: float64

# %%
import numpy as np
dfgby['five_star_ratings'].apply(np.sum, axis=0)
# Out:
# year_published
# 1000       1316
# 1001        144
# 1002       4348
# 1008       5634
# 1010       2777
#          ...
# 2017    6936643
# 2018    5733865
# 2019    2571860
# 2020     369304
# 2021         87
# Name: five_star_ratings, Length: 449, dtype: int64

# %% [markdown]
# #### Иерархические индексы (MultiIndex)
# Иерархические индексы позволяют организовать несколько (два и более) уровней индексирования по одной оси. Другими словави, это способ работать с многомерными данными, представив их в форме с меньшей размерностью.

# %%
# сгенерируем series с multiindex
data = pd.Series(np.random.randn(10),
    index= [ ['a', 'a', 'a', 'b', 'b', 'b', 'с', 'с', 'd', 'd'],
             [1, 2, 3, 1, 2, 3, 1, 2, 2, 3] ]
)
data
# Out:
# a  1    1.402709
#    2   -0.758012
#    3   -0.496959
# b  1   -1.185734
#    2    0.608483
#    3   -1.048379
# с  1    1.312849
#    2    1.453047
# d  2   -0.143597
#    3   -1.485981
# dtype: float64

# %%
# сгенерируем dataframe с multiindex
data = pd.DataFrame(np.random.randn(10,2),
    index= [ ['a', 'a', 'a', 'b', 'b', 'b', 'с', 'с', 'd', 'd'],
             [1, 2, 3, 1, 2, 3, 1, 2, 2, 3] ]
)
data
# Out:
#             0         1
# a 1  0.983048 -1.494938
#   2 -1.205201 -0.510178
#   3  1.057091 -0.700456
# b 1 -1.305619 -0.672075
#   2 -1.370119  1.079065
#   3  0.181180 -0.954709
# с 1  1.329037  1.213280
#   2 -1.354755  0.817831
# d 2 -0.959169 -0.791705
#   3 -0.268272  0.234565

# %%
data.index
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('a', 3),
#             ('b', 1),
#             ('b', 2),
#             ('b', 3),
#             ('с', 1),
#             ('с', 2),
#             ('d', 2),
#             ('d', 3)],
#            )

# %%
# доступ по частичному значению индекса
data.loc['a']
# Out:
#           0         1
# 1  0.983048 -1.494938
# 2 -1.205201 -0.510178
# 3  1.057091 -0.700456

# %%
# доступ по полному значению индекса
data.loc[('a', 1)]
# Out:
# 0    0.983048
# 1   -1.494938
# Name: (a, 1), dtype: float64

# %%
# Можно даже сразу получить значение поля
data.loc[('a', 1), 1]
# Out:
# np.float64(-1.4949382030273883)

# %% [markdown]
# ### 1.3 Предобработка данных
#
# Предобработка данных &ndash; это предварительный этап работы с данными, цель которого &ndash; "почистить" данные от ненужного или дополнить их. Может включать в себя центрирование, нормализацию, сдвиг, вращение, обрезку.
#
# #### Виды проблем в данных
#
# - **Неполные данные**
#   Заказчик выслал не все данные, в них есть пропуски, нет данных за определённый период, есть данные только для части задач. Например, есть рейсы только одной авиакомпании, есть суммы покупок с января по март и с июня по декабрь.
# - **Грязные данные**
#    - данные в плохом или разном формате;
#    - в данных есть мусор, например, смешиваются русские и английские буквы, данные в виде шифра;
#    - разные меры данных, например, часть в метрах, часть в футах;
#    - данные старые, значения признака перемешиваются.
# - **Плохая разметка**
#    - в данных есть ошибки;
#    - разная оценка данных из-за человеческого фактора;
#    - разметка не соответствует реальности;
#    - размеченных данных очень много &ndash; должна быть «золотая середина».
#
# > Чем лучше хотите получить разметку данных, тем больше времени придётся потратить.
#
# - **Данные с утечкой**
#   В данных нужно избегать признаков, от которых явно зависит целевая переменная. Такая ситуация приводит к тому, что во время обучения модель всё предсказывает, но в боевых условиях бесполезна.
#
# #### Работа с пропусками
#
# **Пропуски** &ndash; отсутствие значений в данных. Обычно это случается из-за ошибок человека:
# - забыли, какие данные не внесли;
# - не всё перенесли из другого документа;
# - неверно заполнили документ;
# - случайно удалили часть данных.
#
# Например, при опросе респонденты отвечали только на часть вопросов, не указывая какие-то данные.
#
# ##### Что делать с пропусками?
#
# - **Удалить пропуски**: удалить строки с пропусками, если таких строк немного, или столбцы (признаки) в данных, если их много, и это не повлияет на результат в целом.
# - **Заменить пропуски**: заменить на среднее значение (медианой) или на самый часто попадающийся вариант. Например, опрос респондентов проходил в Москве, вероятнее, большинство &ndash; жители города, а не туристы. Значит, в графе город можно поставить «Москва». Или же по другим данным в документе можно восстановить пол людей, которые его не указали.
# - **Записать новое значение**: например, вместо пропуска в столбце «Пол» указать «не определён».
# - **Заменить алгоритмами МО**: признак можно считать целевой переменной и обучать модель, чтобы предсказать пропущенные значения.

# %% [markdown]
# #### Нормализация признаков
# Некоторые алгоритмы чувствительны к масштабу признаков: если масштаб разный &ndash; алгоритмы хуже сходятся к оптимальным значениям. Один из способов обработки данных &ndash; **нормализация** &ndash; процесс приведения данных к одному масштабу, обеспечивает лучшие условия выборки, изменения, удаления данных.
#
# Базовые методы нормализации:
#
# - **MinMax** нормализация &ndash; приведение данных к масштабу $[0, 1]$.
# - **Стандартная** нормализация &ndash; данные имеют среднее $0$ и стандартное отклонение $1$.
#
# Иногда данные лучше удалить, если они не несут пользы. Например, столбец считался по ошибке и содержит мусор, или признак не имеет полезной информации, или столбец содержит всегда одинаковое значение.

# %% [markdown]
# #### Преобразование признаков, имеющих не нормальное распредление
#
# Один из способов визуализации &ndash; **гистограмма** &ndash; вид диаграммы, показывающий данные в форме столбцов. Демонстрирует распределение данных по выборке внутри столбца и значений в признаке. Позволяет увидеть проблемы или некорректные значения в данных, преобразовать их в наглядную форму и распределить, чтобы облегчить работу.
#
# **Графики Q-Q (квантиль-квантиль)** сравнивают два распределения вероятностей путем построения совместных квантилей. График Q-Q используется для сравнения форм распределений, обеспечивая графическое представление того, насколько подобны или различны положение, масштаб и асимметрия двух распределений.
#
# Многие алгоритмы работают лучше, когда на вход принимают нормально распределённые данные. Один из способов сделать данные «нормальными» &ndash; взять **логарифм**. При этом не должно быть значений, равных $0$, иначе метод `np.log` выдаст бесконечность.
# Если значения всё-таки начинаются с $0$, то перед тем, как взять логарифм, можно прибавить к данным $1$.
# Другой способ &ndash; взять квадратный корень от данных.

# %% [markdown]
# #### Скореллированные признаки
#
# **Correlation plot** &ndash; корреляционный график. Признаки в данных могут иметь сильную корреляцию, то есть линейную зависимость. Если зависимость большая, признаки несут избыточную информацию, поэтому скореллированные признаки лучше удалять.

# %% [markdown]
# #### Поиск выбросов (outliers)
#
# **Выброс** &ndash; результат измерения, который выделяется из общей выборки. Выбросы появляются из-за ошибок в данных и сильно выделяются среди остальных значений. Их нужно искать и удалять, иначе данные будут подстраиваться под них и давать неверный результат.
#
# Как искать выбросы:
# - **Поиск и удаление по порогу**
#   Способ нахождения выбросов, основанный на здравом смысле и методе пристального взгляда. Посмотреть на данные и поискать невозможные и/или нелогичные значения, например, в столбце «высота здания» стоит $30$ км.
# - **Поиск с помощью статистики**
#   Поиск с помощью здравого смысла трудно автоматизировать, поэтому эффективнее статистические методы. Например, поиск по отклонению или по распределению $IQR$ (interquartile range, межквартильное расстояние).
# - **Поиск с помощью DBSCAN**
#   Поиск с помощью методов кластеризации, один из таких методов &ndash; DBSCAN, который может автоматически находить шум в данных.
#
# Разные способы поиска выбросов могут давать разные результаты. Не всегда выделяющееся значение будет являться выбросом, возможно, у нас пока просто не хватает данных.

# %% [markdown]
# #### Создание новых признаков &ndash; feature engineering
#
# **Feature Engineering** &ndash; способ создания признаков, техника решения задач МО, которая увеличивает качество разрабатываемых алгоритмов. Превращает специфичные данные в понятные для модели векторы.
#
# Способы:
# - **Ручное создание признаков**
#   Новые признаки можно создавать на основе имеющихся, если понятно, что означает тот или иной признак. Техника может значительно улучшить модель, но требуется погружение в предметную область. Например, зная массу и рост человека, можно посчитать индекс массы тела; зная координаты места нарушения ПДД и центра города, можно посчитать расстояние между ними.
# - **Полиномиальные признаки**
#   Например, попарное перемножение имеющихся столбцов, чтобы получить нелинейные комбинации признаков. Другой пример &ndash; возведение признаков в квадрат или корень из признака, чтобы получить искусственные признаки.
# - **Dummy-переменные**
#   Между категориальными признаками не всегда есть порядок, поэтому их следует заменять на dummy-переменные, в виде цифр, чтобы алгоритм подумал, что в данных есть порядок.
#   > Например, лев, тигр, медведь лучше записать как $0$, $1$, $2$. Расстояние между «лев» и «тигр» равно $1$, а между «лев» и «медведь» &ndash; $2$, хотя это не так. Решение &ndash; создать новые признаки по количеству категорий. Для признака «лев» значение будет $1$, если это лев, иначе $0$. Теперь расстояния между всеми признаками равны $1$.
# - **Работа с датой/временем**
#   Обычно дата &ndash; это строка, похожая на «2005-06-02». В таком виде признак имеет мало смысла, но его можно разделить на набор других признаков. Модель не принимает текст, поэтому заменяем его на набор других числовых признаков. Например, день, месяц, год или день недели, праздник/выходной.
# - **Статистики по наборам признаков**
#   Если в данных есть признаки, описывающие значение в разные моменты времени, то они могут быть полезными. Например, зарплата_2016, зарплата_2017, зарплата_2018. Отсюда можно вытащить среднюю зарплату за $3$ года, медианную зарплату, динамику зарплаты, максимальную и минимальную зарплату.

# %% [markdown]
# ### 1.4 Визуализация данных
#
# Библиотеки
#
# - [matplotlib](https://matplotlib.org/)
#     Python-библиотека для визуализации данных.
# - [seaborn](https://seaborn.pydata.org/index.html)
#     Библиотека для создания статистических графиков на Python. Она основывается на `matplotlib` и тесно взаимодействует со структурами данных `pandas`.
# - [plotly](https://plotly.com/python/)
#    Библиотека для визуализации данных.
#    - Фреймворк [Dash](https://dash.plotly.com/).
#
# Гайды по `matplotlib`:
# - [Quick start guide](https://matplotlib.org/stable/users/explain/quick_start.html)
# - [Pyplot tutorial](https://matplotlib.org/stable/tutorials/pyplot.html)
# - [Examples](https://matplotlib.org/stable/gallery/index.html)
# - [Interactive Plotting in IPython](https://ipython.readthedocs.io/en/stable/interactive/plotting.html)
# - [Enable interactive mode - matplotlib.pyplot.ion](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.ion.html)
#
# Гайды по `seaborn`:
# - [Tutorial](https://seaborn.pydata.org/tutorial.html)
# - [Visualizing categorical data](https://seaborn.pydata.org/tutorial/categorical.html)
#
# Гайды по `plotly`:
# - [Шпаргалка по визуализации данных в Python с помощью Plotly @ Хабр](https://habr.com/ru/articles/502958/)
# - [Забудьте о matplotlib: визуализация данных в Python вместе с plotly @ proglib](https://proglib.io/p/plotly)
# - [Визуализация данных с помощью Python Dash @ Хабр](https://habr.com/ru/companies/otus/articles/716190/)
#
# Гайды по `pandas`:
# - [pandas.DataFrame.plot](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)
# - [Chart visualization](https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html)
#
# Гайды:
# - [Открытый курс машинного обучения. Тема 2: Визуализация данных c Python](https://habr.com/ru/company/ods/blog/323210/)

# %% [markdown]
# ### 1.5 Датасет
#
# [Goodreads Books - 31 Features](https://www.kaggle.com/datasets/austinreese/goodreads-books)
#
# | Признак                | Описание                                                                                                    |
# |------------------------|-------------------------------------------------------------------------------------------------------------|
# | id                     | id книги                                                                                                    |
# | title                  | Название книги                                                                                              |
# | link                   | Ссылка на Goodreads                                                                                         |
# | series                 | Название цикла, если книга является частью многоциколового произведения                                     |
# | cover_link             | Ссылка на обложку книги                                                                                     |
# | author                 | Список авторов книжного произведения                                                                        |
# | author_link            | Ссылка на запись об авторах книжного произведения                                                           |
# | rating_count           | Количество выставленных оценок на книжное произведение                                                      |
# | review_count           | Количество оставленных отзывов на книжное произведение                                                      |
# | average_rating         | Средняя оценка книжного произведения                                                                        |
# | five_star_ratings      | Количество выставленных оценок на книжное произведение "5 звезд"                                            |
# | four_star_ratings      | Количество выставленных оценок на книжное произведение "4 звезды"                                           |
# | three_star_ratings     | Количество выставленных оценок на книжное произведение "3 звезды"                                           |
# | two_star_ratings       | Количество выставленных оценок на книжное произведение "2 звезды"                                           |
# | one_star_ratings       | Количество выставленных оценок на книжное произведение "1 звезда"                                           |
# | number_of_pages        | Количество страниц в книжном произведении                                                                   |
# | date_published         | Дата выхода книги в печатном издании                                                                        |
# | publisher              | Название издательства                                                                                       |
# | original_title         | Исходное название книги                                                                                     |
# | genre_and_votes        | Список указанных пользователями жанров в виде <жанр1 N1>, <жанр2 N2>, где N1, N2 &ndash; количество "меток" |
# | isbn                   | ISBN номер книжного произведения                                                                            |
# | isbn13                 | 13-тизначный ISBN номер книжного произведения                                                               |
# | asin                   | Amazon Standard Identification Number &ndash; артикул на площадке Amazon                                    |
# | settings               | Место (или несколько), в котором происходят описываемые в книге события                                     |
# | characters             | Имена основных персонажей в книге                                                                           |
# | awards                 | Список названий присужденных книжному произведению премий (наград)                                          |
# | amazon_redirect_link   | URL ссылка редиректа на площадку Amazon                                                                     |
# | worldcat_redirect_link | URL ссылка редиректа на Goodread's WorldCat                                                                 |
# | recommended_books      | Список id рекомендуемых книг с Goodreads                                                                    |
# | books_in_series        | Список id книг, входящих в одноименный цикл                                                                 |
# | description            | Синопсис                                                                                                    |

# %%
import pandas as pd
import numpy as np
from pathlib import Path
# путь к папке с данными
data_path = "../lecture_1/data"
# датасет: Goodreads Books - 31 Features: https://www.kaggle.com/datasets/austinreese/goodreads-books
df = pd.read_csv(Path(data_path, 'goodreads_books.csv'))
df.info()
df.head(10)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 52199 entries, 0 to 52198
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      52199 non-null  int64
#  1   title                   52199 non-null  str
#  2   link                    52199 non-null  str
#  3   series                  23319 non-null  str
#  4   cover_link              51592 non-null  str
#  5   author                  52199 non-null  str
#  6   author_link             52199 non-null  str
#  7   rating_count            52199 non-null  int64
#  8   review_count            52199 non-null  int64
#  9   average_rating          52199 non-null  float64
#  10  five_star_ratings       52199 non-null  int64
#  11  four_star_ratings       52199 non-null  int64
#  12  three_star_ratings      52199 non-null  int64
#  13  two_star_ratings        52199 non-null  int64
#  14  one_star_ratings        52199 non-null  int64
#  15  number_of_pages         49869 non-null  float64
#  16  date_published          51339 non-null  str
#  17  publisher               48563 non-null  str
#  18  original_title          39250 non-null  str
#  19  genre_and_votes         49359 non-null  str
#  20  isbn                    40316 non-null  str
#  21  isbn13                  39507 non-null  str
#  22  asin                    5236 non-null   str
#  23  settings                11515 non-null  str
#  24  characters              13695 non-null  str
#  25  awards                  10626 non-null  str
#  26  amazon_redirect_link    52199 non-null  str
#  27  worldcat_redirect_link  48214 non-null  str
#  28  recommended_books       48205 non-null  str
#  29  books_in_series         22078 non-null  str
#  30  description             49624 non-null  str
# dtypes: float64(2), int64(8), str(21)
# memory usage: 12.3 MB
#         id                                              title  \
# 0   630104                                       Inner Circle
# 1     9487                                  A Time to Embrace
# 2  6050894                                           Take Two
# 3    39030                                          Reliquary
# 4      998  The Millionaire Next Door: The Surprising Secr...
# 5   311164                                        Black Sheep
# 6    32105                                          Sylvester
# 7   377993                                                Joe
# 8    71292                                   Asterix the Gaul
# 9   821003                            When We Were Very Young
#
#                                                 link                series  \
# 0  https://www.goodreads.com//book/show/630104.In...          (Private #5)
# 1  https://www.goodreads.com//book/show/9487.A_Ti...    (Timeless Love #2)
# 2  https://www.goodreads.com//book/show/6050894-t...   (Above the Line #2)
# 3  https://www.goodreads.com//book/show/39030.Rel...       (Pendergast #2)
# 4  https://www.goodreads.com//book/show/998.The_M...                   NaN
# 5  https://www.goodreads.com//book/show/311164.Bl...                   NaN
# 6  https://www.goodreads.com//book/show/32105.Syl...                   NaN
# 7    https://www.goodreads.com//book/show/377993.Joe                   NaN
# 8  https://www.goodreads.com//book/show/71292.Ast...         (AstÃ©rix #1)
# 9  https://www.goodreads.com//book/show/821003.Wh...  (Winnie-the-Pooh #3)
#
#                                           cover_link  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...
# 1  https://i.gr-assets.com/images/S/compressed.ph...
# 2  https://i.gr-assets.com/images/S/compressed.ph...
# 3  https://i.gr-assets.com/images/S/compressed.ph...
# 4  https://i.gr-assets.com/images/S/compressed.ph...
# 5  https://i.gr-assets.com/images/S/compressed.ph...
# 6  https://i.gr-assets.com/images/S/compressed.ph...
# 7  https://i.gr-assets.com/images/S/compressed.ph...
# 8  https://i.gr-assets.com/images/S/compressed.ph...
# 9  https://i.gr-assets.com/images/S/compressed.ph...
#
#                                               author  \
# 0                          Kate Brian, Julian Peploe
# 1                                    Karen Kingsbury
# 2                                    Karen Kingsbury
# 3                     Douglas Preston, Lincoln Child
# 4                Thomas J. Stanley, William D. Danko
# 5                                    Georgette Heyer
# 6                         Georgette Heyer, Joan Wolf
# 7                                        Larry Brown
# 8  RenÃ© Goscinny, Albert Uderzo, Anthea Bell, De...
# 9                      A.A. Milne, Ernest H. Shepard
#
#                                          author_link  rating_count  \
# 0  https://www.goodreads.com/author/show/94091.Ka...          7597
# 1  https://www.goodreads.com/author/show/3159984....          4179
# 2  https://www.goodreads.com/author/show/3159984....          6288
# 3  https://www.goodreads.com/author/show/12577.Do...         38382
# 4  https://www.goodreads.com/author/show/659.Thom...         72168
# 5  https://www.goodreads.com/author/show/18067.Ge...          9538
# 6  https://www.goodreads.com/author/show/18067.Ge...         13473
# 7  https://www.goodreads.com/author/show/31125.La...          2722
# 8  https://www.goodreads.com/author/show/1041311....         23324
# 9  https://www.goodreads.com/author/show/81466.A_...         21973
#
#    review_count  average_rating  five_star_ratings  four_star_ratings  \
# 0           196            4.03               3045               2323
# 1           177            4.35               2255               1290
# 2           218            4.23               3000               2020
# 3          1424            4.01              12711              15407
# 4          3217            4.04              27594              25219
# 5           775            4.05               3298               3831
# 6          1141            4.11               5216               5225
# 7           260            4.18               1111               1119
# 8           534            4.17              10488               7797
# 9           532            4.30              11753               6063
#
#    three_star_ratings  two_star_ratings  one_star_ratings  number_of_pages  \
# 0                1748               389                92            220.0
# 1                 518                93                23            400.0
# 2                1041               183                44            320.0
# 3                8511              1429               324            464.0
# 4               14855              3414              1086            258.0
# 5                2042               304                63            252.0
# 6                2470               434               128            410.0
# 7                 385                76                31            368.0
# 8                3942               712               385             48.0
# 9                3349               623               185            100.0
#
#       date_published                                publisher  \
# 0   January 1st 2007  Simon  Schuster Books for Young Readers
# 1  October 29th 2006                            Thomas Nelson
# 2   January 1st 2009                                Zondervan
# 3               1997                                Tor Books
# 4  October 28th 1995                            Gallery Books
# 5     March 1st 1966                                    Arrow
# 6               1957                                Harlequin
# 7               1980                          Algonquin Books
# 8     July 14th 1960                 Orion Books Ltd., London
# 9      November 1924                              E.P. Dutton
#
#                                       original_title  \
# 0                                       Inner Circle
# 1                                                NaN
# 2                                           Take Two
# 3                                          Reliquary
# 4  The Millionaire Next Door: The Surprising Secr...
# 5                                        Black Sheep
# 6                     Sylvester, or The Wicked Uncle
# 7                                                Joe
# 8                                AstÃ©rix le Gaulois
# 9                            When We Were Very Young
#
#                                      genre_and_votes        isbn  \
# 0            Young Adult 161, Mystery 45, Romance 32  1416950419
# 1  Christian Fiction 114, Christian 45, Fiction 3...  1595542329
# 2    Christian Fiction 174, Christian 81, Fiction 58         NaN
# 3  Thriller 626, Mystery 493, Horror 432, Fiction...  0765354950
# 4  Economics-Finance 1162, Nonfiction 910, Busine...  0671015206
# 5  Romance 550, Historical-Historical Fiction 316...  0099468034
# 6  Romance 725, Historical-Historical Fiction 395...  0373836082
# 7  Fiction 106, American-Southern 26, Gothic-Sout...  1565124138
# 8  Sequential Art-Comics 947, Sequential Art-Grap...  0752866052
# 9  Poetry 599, Childrens 384, Classics 301, Ficti...  0525444459
#
#           isbn13 asin                                           settings  \
# 0  9781416950417  NaN                                                NaN
# 1  9781595542328  NaN                                                NaN
# 2            NaN  NaN                Bloomington, Indiana(United States)
# 3  9780765354952  NaN  New York State(United States) New York City, N...
# 4  9780671015206  NaN                                                NaN
# 5  9780099468035  NaN                                                NaN
# 6  9780373836086  NaN                                                NaN
# 7  9781565124134  NaN                                                NaN
# 8  9780752866055  NaN                         Armorica, Brittany(France)
# 9  9780525444459  NaN                                                NaN
#
#                                           characters  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Aloysius X.L. Pendergast, Margo Green, William...
# 4                                                NaN
# 5                Abigail Wendover, Miles Calverleigh
# 6          Phoebe Marlow, Sylvester, Duke of Salford
# 7                                                NaN
# 8  Asterix, Obelix, Julius Caesar, Panoramix, Ass...
# 9                                                NaN
#
#                                               awards  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Independent Publisher Book Award (IPPY) Nomine...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                 amazon_redirect_link  \
# 0  https://www.goodreads.com//book_link/follow/17...
# 1  https://www.goodreads.com//book_link/follow/17...
# 2  https://www.goodreads.com//book_link/follow/17...
# 3  https://www.goodreads.com//book_link/follow/17...
# 4  https://www.goodreads.com//book_link/follow/17...
# 5  https://www.goodreads.com//book_link/follow/17...
# 6  https://www.goodreads.com//book_link/follow/17...
# 7  https://www.goodreads.com//book_link/follow/17...
# 8  https://www.goodreads.com//book_link/follow/17...
# 9  https://www.goodreads.com//book_link/follow/17...
#
#                               worldcat_redirect_link  \
# 0  https://www.goodreads.com//book_link/follow/8?...
# 1  https://www.goodreads.com//book_link/follow/8?...
# 2  https://www.goodreads.com//book_link/follow/8?...
# 3  https://www.goodreads.com//book_link/follow/8?...
# 4  https://www.goodreads.com//book_link/follow/8?...
# 5  https://www.goodreads.com//book_link/follow/8?...
# 6  https://www.goodreads.com//book_link/follow/8?...
# 7  https://www.goodreads.com//book_link/follow/8?...
# 8  https://www.goodreads.com//book_link/follow/8?...
# 9  https://www.goodreads.com//book_link/follow/8?...
#
#                                    recommended_books  \
# 0  726458, 726458, 1537534, 3047848, 1651302, 304...
# 1  127352, 127352, 40642197, 127353, 127354, 3891...
# 2  706250, 706250, 666481, 11942636, 706241, 1273...
# 3  39026, 39026, 11007668, 3986318, 51887330, 194...
# 4  1052, 1052, 763362, 69571, 78427, 30186948, 10...
# 5  6528786, 6528786, 311125, 376509, 40487683, 28...
# 6  311125, 311125, 40188318, 40487683, 222754, 13...
# 7  972106, 972106, 294731, 24847, 51197807, 17047...
# 8  2895675, 2895675, 238055, 18211116, 122447, 12...
# 9  6192692, 6192692, 543505, 20413, 34053, 563098...
#
#                                      books_in_series  \
# 0  381489, 381501, 352428, 630103, 1783281, 17832...
# 1                                             115036
# 2                         4010795, 40792877, 7306261
# 3  67035, 39031, 39033, 136637, 136638, 30068, 39...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  122439, 122408, 122401, 122421, 122410, 122404...
# 9                              99107, 776407, 821000
#
#                                          description
# 0  Reed Brennan arrived at Easton Academy expecti...
# 1  Ideje az Ã¶lelÃ©snek TÃ¶rtÃ©net a remÃ©nyrÅl,...
# 2  Filmmakers Chase Ryan and Keith Ellison have c...
# 3                                                NaN
# 4  The incredible national bestseller that is cha...
# 5  With her high-spirited intelligence and good l...
# 6  When the news went out that Sylvester Rayne, t...
# 7  Now a major motion picture starring Nicolas Ca...
# 8  The year is 50BC, and all Gaul is occupied. On...
# 9                                                NaN

# %% [markdown]
# ### 1.6 Предобработка данных датасета
# #### Дропаем ненужные очевидные признаки
#
# Уберем из датафрейма следующие признаки:
# - `link`: ссылка на Goodreads
# - `cover_link`: ссылка на обложку книги
# - `author_link`: ссылка на запись об авторах книжного произведения
# - `original_title`: исходное название книги
# - `isbn`: ISBN номер книжного произведения
# - `isbn13`: 13-тизначный ISBN номер книжного произведения
# - `asin`: Amazon Standard Identification Number &ndash; артикул на площадке Amazon
# - `amazon_redirect_link`: URL ссылка редиректа на площадку Amazon
# - `worldcat_redirect_link`: URL ссылка редиректа на Goodread's WorldCat
# - `recommended_books`: список id рекомендуемых книг с Goodreads

# %% [markdown]
# #### Парсим год выхода

# %% [markdown]
# ##### Избавимся от NaN

# %%
print(f"{df[df['date_published'].isna()].shape[0]} out of {df['date_published'].shape[0]} is NaN")
# Out:
# 860 out of 52199 is NaN

# %%
df.drop(df[df['date_published'].isna()].index, inplace=True)
df['date_published'].shape[0]
# Out:
# 51339

# %%
df['date_published'].head(10)
# Out:
# 0     January 1st 2007
# 1    October 29th 2006
# 2     January 1st 2009
# 3                 1997
# 4    October 28th 1995
# 5       March 1st 1966
# 6                 1957
# 7                 1980
# 8       July 14th 1960
# 9        November 1924
# Name: date_published, dtype: str

# %% [markdown]
# ##### Добавим признак `Год выхода` и спарсим год из даты

# %%
# см. https://regex101.com/
df.loc[:, 'year_published'] = df['date_published'].str.extract(r'(\d{4})').to_numpy().flatten()
df.drop(df[df['year_published'].isna()].index, inplace=True)
df['year_published'] = df['year_published'].astype(int)
# дропаем дату выхода
df.drop(columns=['date_published'], inplace=True)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 51190 entries, 0 to 52198
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      51190 non-null  int64
#  1   title                   51190 non-null  str
#  2   link                    51190 non-null  str
#  3   series                  23034 non-null  str
#  4   cover_link              50757 non-null  str
#  5   author                  51190 non-null  str
#  6   author_link             51190 non-null  str
#  7   rating_count            51190 non-null  int64
#  8   review_count            51190 non-null  int64
#  9   average_rating          51190 non-null  float64
#  10  five_star_ratings       51190 non-null  int64
#  11  four_star_ratings       51190 non-null  int64
#  12  three_star_ratings      51190 non-null  int64
#  13  two_star_ratings        51190 non-null  int64
#  14  one_star_ratings        51190 non-null  int64
#  15  number_of_pages         49530 non-null  float64
#  16  publisher               48246 non-null  str
#  17  original_title          38775 non-null  str
#  18  genre_and_votes         48562 non-null  str
#  19  isbn                    39911 non-null  str
#  20  isbn13                  39140 non-null  str
#  21  asin                    5179 non-null   str
#  22  settings                11436 non-null  str
#  23  characters              13604 non-null  str
#  24  awards                  10593 non-null  str
#  25  amazon_redirect_link    51190 non-null  str
#  26  worldcat_redirect_link  47705 non-null  str
#  27  recommended_books       47444 non-null  str
#  28  books_in_series         21843 non-null  str
#  29  description             48897 non-null  str
#  30  year_published          51190 non-null  int64
# dtypes: float64(2), int64(9), str(20)
# memory usage: 12.5 MB

# %% [markdown]
# #### Удаляем скобки в столбце `series`

# %%
df.series.head(10)
# Out:
# 0            (Private #5)
# 1      (Timeless Love #2)
# 2     (Above the Line #2)
# 3         (Pendergast #2)
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8           (AstÃ©rix #1)
# 9    (Winnie-the-Pooh #3)
# Name: series, dtype: str

# %%
df['series'] = df['series'].str.strip('()')
df.series.head(10)
# Out:
# 0            Private #5
# 1      Timeless Love #2
# 2     Above the Line #2
# 3         Pendergast #2
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8           AstÃ©rix #1
# 9    Winnie-the-Pooh #3
# Name: series, dtype: str

# %% [markdown]
# Отделим порядковый номер книги в книжном издании `#N` от самого названия цикла.

# %%
df['series'].str.extract(r'( *#\d+ *)')
# Out:
#          0
# 0       #5
# 1       #2
# 2       #2
# 3       #2
# 4      NaN
# ...    ...
# 52194  NaN
# 52195  NaN
# 52196  NaN
# 52197   #4
# 52198  NaN
#
# [51190 rows x 1 columns]

# %%
# сначала проверим результат замены с regexp'ом
df['series'].str.replace(r'( *#\d+ *)', '', regex=True)
# Out:
# 0               Private
# 1         Timeless Love
# 2        Above the Line
# 3            Pendergast
# 4                   NaN
#               ...
# 52194               NaN
# 52195               NaN
# 52196               NaN
# 52197           Private
# 52198               NaN
# Name: series, Length: 51190, dtype: str

# %%
df['series'] = df['series'].str.replace(r'( *#\d+ *)', '', regex=True)
df.series.head(10)
# Out:
# 0            Private
# 1      Timeless Love
# 2     Above the Line
# 3         Pendergast
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8           AstÃ©rix
# 9    Winnie-the-Pooh
# Name: series, dtype: str

# %% [markdown]
# #### Проанализируем `books_in_series`

# %%
df.books_in_series.head(10)
# Out:
# 0    381489, 381501, 352428, 630103, 1783281, 17832...
# 1                                               115036
# 2                           4010795, 40792877, 7306261
# 3    67035, 39031, 39033, 136637, 136638, 30068, 39...
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8    122439, 122408, 122401, 122421, 122410, 122404...
# 9                                99107, 776407, 821000
# Name: books_in_series, dtype: str

# %% [markdown]
# #### Добавим признак `books_in_series_count` &ndash; количество книг в цикле
# > Пример того самого *feature engineering*.

# %%
df['books_in_series_count'] = [len([idx for idx in x.split(',')])
                               if pd.notna(x)
                               else 0
                               for x in df['books_in_series']]
df['books_in_series_count'] += 1  # не забываем посчитать и саму книгу
df['books_in_series_count'].head(10)
# Out:
# 0    11
# 1     2
# 2     4
# 3    11
# 4     1
# 5     1
# 6     1
# 7     1
# 8    11
# 9     4
# Name: books_in_series_count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 51190 entries, 0 to 52198
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      51190 non-null  int64
#  1   title                   51190 non-null  str
#  2   link                    51190 non-null  str
#  3   series                  23034 non-null  str
#  4   cover_link              50757 non-null  str
#  5   author                  51190 non-null  str
#  6   author_link             51190 non-null  str
#  7   rating_count            51190 non-null  int64
#  8   review_count            51190 non-null  int64
#  9   average_rating          51190 non-null  float64
#  10  five_star_ratings       51190 non-null  int64
#  11  four_star_ratings       51190 non-null  int64
#  12  three_star_ratings      51190 non-null  int64
#  13  two_star_ratings        51190 non-null  int64
#  14  one_star_ratings        51190 non-null  int64
#  15  number_of_pages         49530 non-null  float64
#  16  publisher               48246 non-null  str
#  17  original_title          38775 non-null  str
#  18  genre_and_votes         48562 non-null  str
#  19  isbn                    39911 non-null  str
#  20  isbn13                  39140 non-null  str
#  21  asin                    5179 non-null   str
#  22  settings                11436 non-null  str
#  23  characters              13604 non-null  str
#  24  awards                  10593 non-null  str
#  25  amazon_redirect_link    51190 non-null  str
#  26  worldcat_redirect_link  47705 non-null  str
#  27  recommended_books       47444 non-null  str
#  28  books_in_series         21843 non-null  str
#  29  description             48897 non-null  str
#  30  year_published          51190 non-null  int64
#  31  books_in_series_count   51190 non-null  int64
# dtypes: float64(2), int64(10), str(20)
# memory usage: 12.9 MB

# %%
# количество "серийных" книжных изданий (НЕ серий, а именно книг, входящих в книжные циклы
len(df[df['books_in_series_count'] > 1])
# Out:
# 21843

# %%
# количество книжных циклов
df['series'].unique().shape
# Out:
# (11590,)

# %% [markdown]
# #### Проанализируем `awards`

# %%
pd.set_option('display.width', 1000)
df[df.awards.notna()].awards.head(10)
# Out:
# 4     Independent Publisher Book Award (IPPY) Nomine...
# 10    Romantic Times Reviewers' Choice Award (RT Awa...
# 13    Goodreads Choice Award Nominee for Nonfiction ...
# 15                                    SFBC Award (1991)
# 16    International Napoleonic Society Literary Awar...
# 26    Theakston Old Peculier Crime Novel of the Year...
# 28    BTBA Best Translated Book Award Nominee for Fi...
# 30    Romantic Times Reviewers' Choice Award (RT Awa...
# 31    Mythopoeic Fantasy Award Nominee for Children'...
# 35    ALA Alex Award (2010), Corine Internationaler ...
# Name: awards, dtype: str

# %%
df.awards[10]
# Out:
# "Romantic Times Reviewers' Choice Award (RT Award) for Fantasy Adventure (2015), Goodreads Choice Award Nominee for Fantasy (2015)"

# %% [markdown]
# Допустим, мы хотим в данном признаке оставить перечисление названий книжных премий без указания года присуждения.

# %%
df[df.awards.notna()].awards.str.replace(r' *\(\d+\) *', '', regex=True)
# Out:
# 4        Independent Publisher Book Award (IPPY) Nomine...
# 10       Romantic Times Reviewers' Choice Award (RT Awa...
# 13           Goodreads Choice Award Nominee for Nonfiction
# 15                                              SFBC Award
# 16         International Napoleonic Society Literary Award
#                                ...
# 52190    Anthony Award for Best First Novel, Grand Prix...
# 52191    Barry Award Nominee for Best Novel, Dilys Awar...
# 52193                           Edgar Award for Best Novel
# 52195    Goodreads Choice Award for Nonfiction, Waterst...
# 52196    Austrian National Prize, City of Vienna Juveni...
# Name: awards, Length: 10593, dtype: str

# %%
df.awards = df.awards.str.replace(r' *\(\d+\) *', '', regex=True)
df[df.awards.notna()].awards.head(10)
# Out:
# 4     Independent Publisher Book Award (IPPY) Nomine...
# 10    Romantic Times Reviewers' Choice Award (RT Awa...
# 13        Goodreads Choice Award Nominee for Nonfiction
# 15                                           SFBC Award
# 16      International Napoleonic Society Literary Award
# 26    Theakston Old Peculier Crime Novel of the Year...
# 28    BTBA Best Translated Book Award Nominee for Fi...
# 30    Romantic Times Reviewers' Choice Award (RT Awa...
# 31    Mythopoeic Fantasy Award Nominee for Children'...
# 35    ALA Alex Award, Corine Internationaler Buchpre...
# Name: awards, dtype: str

# %%
df.awards[10]
# Out:
# "Romantic Times Reviewers' Choice Award (RT Award) for Fantasy Adventure, Goodreads Choice Award Nominee for Fantasy"

# %% [markdown]
# #### Добавим признак `awards_count`

# %%
df['awards_count'] = [len([idx for idx in x.split(',')])
                      if pd.notna(x)
                      else 0
                      for x in df['awards']]
df[df['awards_count'] > 0]['awards_count'].head(10)
# Out:
# 4     1
# 10    2
# 13    1
# 15    1
# 16    1
# 26    1
# 28    3
# 30    2
# 31    1
# 35    2
# Name: awards_count, dtype: int64

# %% [markdown]
# ##### Какая самая титулованная книга?

# %%
df.loc[df['awards_count'].idxmax(), ['title', 'awards', 'awards_count']]
# Out:
# title                                            The Hunger Games
# awards          Locus Award Nominee for Best Young Adult Book,...
# awards_count                                                   40
# Name: 41514, dtype: object

# %% [markdown]
# #### Проанализируем признак `author`

# %%
df['author'].head(10)
# Out:
# 0                            Kate Brian, Julian Peploe
# 1                                      Karen Kingsbury
# 2                                      Karen Kingsbury
# 3                       Douglas Preston, Lincoln Child
# 4                  Thomas J. Stanley, William D. Danko
# 5                                      Georgette Heyer
# 6                           Georgette Heyer, Joan Wolf
# 7                                          Larry Brown
# 8    RenÃ© Goscinny, Albert Uderzo, Anthea Bell, De...
# 9                        A.A. Milne, Ernest H. Shepard
# Name: author, dtype: str

# %%
df['author'][0]
# Out:
# 'Kate Brian, Julian Peploe'

# %% [markdown]
# Преобразуем строку в массив строк.

# %%
df['author'] = [[idx for idx in x.split(',')] for x in df['author']]
df['author'].head(10)
# Out:
# 0                         [Kate Brian,  Julian Peploe]
# 1                                    [Karen Kingsbury]
# 2                                    [Karen Kingsbury]
# 3                    [Douglas Preston,  Lincoln Child]
# 4               [Thomas J. Stanley,  William D. Danko]
# 5                                    [Georgette Heyer]
# 6                        [Georgette Heyer,  Joan Wolf]
# 7                                        [Larry Brown]
# 8    [RenÃ© Goscinny,  Albert Uderzo,  Anthea Bell,...
# 9                     [A.A. Milne,  Ernest H. Shepard]
# Name: author, dtype: object

# %%
df['author'][0]
# Out:
# ['Kate Brian', ' Julian Peploe']

# %% [markdown]
# #### Проанализируем признак `genre_and_votes`

# %%
df.genre_and_votes
# Out:
# 0                  Young Adult 161, Mystery 45, Romance 32
# 1        Christian Fiction 114, Christian 45, Fiction 3...
# 2          Christian Fiction 174, Christian 81, Fiction 58
# 3        Thriller 626, Mystery 493, Horror 432, Fiction...
# 4        Economics-Finance 1162, Nonfiction 910, Busine...
#                                ...
# 52194    Romance-Historical Romance 335, Romance 312, H...
# 52195    Nonfiction 1307, Short Stories 766, Writing-Es...
# 52196    Fiction 13, Childrens 11, Historical-Historica...
# 52197              Young Adult 182, Mystery 52, Romance 34
# 52198    Biography 176, Nonfiction 171, Politics 165, B...
# Name: genre_and_votes, Length: 51190, dtype: str

# %% [markdown]
# Возможно, информация о количестве проставленных тегов может представлять для нас какой-то интерес. Например, получить популярность того или иного жанра.
# > Вдруг какой-нибудь жанр наиболее предпочитаем пользователем, и ему везде "мерещится" наличие элементов этого жанра в прочитанных им произведениях.
#
# Мы же просто уберем количество проставленных тегов.

# %%
# тестовая проверка удаления количества проставленных тегов
df.genre_and_votes.str.replace(r'( *\d+ *)', '', regex=True)
# Out:
# 0                            Young Adult, Mystery, Romance
# 1           Christian Fiction, Christian, Fiction, Romance
# 2                    Christian Fiction, Christian, Fiction
# 3                       Thriller, Mystery, Horror, Fiction
# 4        Economics-Finance, Nonfiction, Business, Finan...
#                                ...
# 52194    Romance-Historical Romance, Romance, Historica...
# 52195    Nonfiction, Short Stories, Writing-Essays, Aut...
# 52196    Fiction, Childrens, Historical-Historical Fict...
# 52197                        Young Adult, Mystery, Romance
# 52198    Biography, Nonfiction, Politics, Biography-Aut...
# Name: genre_and_votes, Length: 51190, dtype: str

# %%
df.genre_and_votes.str.replace(r'(, )', ',', regex=True)
# Out:
# 0                    Young Adult 161,Mystery 45,Romance 32
# 1        Christian Fiction 114,Christian 45,Fiction 33,...
# 2            Christian Fiction 174,Christian 81,Fiction 58
# 3          Thriller 626,Mystery 493,Horror 432,Fiction 422
# 4        Economics-Finance 1162,Nonfiction 910,Business...
#                                ...
# 52194    Romance-Historical Romance 335,Romance 312,His...
# 52195    Nonfiction 1307,Short Stories 766,Writing-Essa...
# 52196    Fiction 13,Childrens 11,Historical-Historical ...
# 52197                Young Adult 182,Mystery 52,Romance 34
# 52198    Biography 176,Nonfiction 171,Politics 165,Biog...
# Name: genre_and_votes, Length: 51190, dtype: str

# %%
# дропаем NaN и вносим изменения
df.dropna(subset=['genre_and_votes'], inplace = True)
df.genre_and_votes = df.genre_and_votes.str.replace(r'( *\d+ *)', '', regex=True)
df.genre_and_votes = df.genre_and_votes.str.replace(', ', ',')
df.genre_and_votes[8]
# Out:
# 'Sequential Art-Comics,Sequential Art-Graphic Novels,Sequential Art-Bande DessinÃ©e,Fiction,Humor,Cultural-France'

# %% [markdown]
# Можно заметить, что помимо жанров имеются поджанры. Иерархическую структуру данных этого признака можно отразить в датафрейме путем дублирования данных (с точки зрения основной сущности &ndash; записи о книжном издании): ввести признаки `genre` и `subgenre`, например. И на какой-то стадии обработки и/или анализа данных по жанрам задать MultiIndex `genre` &rarr; `subgenre`.

# %% [markdown]
# Нужные нам регулярки для выделения:
# - жанра &ndash; все, что идет до разделителя "-": `([\w ]+)(?>-)`
# - поджанра &ndash; все, что идет после разделителя "-": `(?<=-)([\w ]+)`

# %%
# поджанры
df.genre_and_votes.str.findall(r'(?<=-)([\w ]+)')
# Out:
# 0                                                       []
# 1                                                       []
# 2                                                       []
# 3                                                       []
# 4        [Finance, Personal Finance, Money, Personal De...
#                                ...
# 52194    [Historical Romance, Erotica, Historical Fiction]
# 52195                      [Essays, Memoir, Coming Of Age]
# 52196                                 [Historical Fiction]
# 52197                                                   []
# 52198                              [Autobiography, Memoir]
# Name: genre_and_votes, Length: 48562, dtype: object

# %%
# жанры
df.genre_and_votes.str.findall(r'([\w ]+)(?>-)')
# см. https://stackoverflow.com/a/74722529
# Out:
# 0                                               []
# 1                                               []
# 2                                               []
# 3                                               []
# 4        [Economics, Finance, Currency, Self Help]
#                            ...
# 52194         [Romance, Adult Fiction, Historical]
# 52195        [Writing, Autobiography, Young Adult]
# 52196                                 [Historical]
# 52197                                           []
# 52198                   [Biography, Autobiography]
# Name: genre_and_votes, Length: 48562, dtype: object

# %% [markdown]
# > В Python &leq; 3.10 данная конструкция выполнится с ошибкой, так как поддержка некоторых элементов синтаксиса регэкспа добавлена в версии 3.11.
# > Подробнее:
# > - [Python Regex - Unknown extension "?>" @ StackOverflow](https://stackoverflow.com/questions/74721240/python-regex-unknown-extension/74722529)
# > - [Сверхжадные квантификаторы @ Хабр](https://habr.com/ru/articles/55863/)
#
# В случае успеха мы увидим, что регэкспом мы поймали жанры, у которых есть поджанр, но пропустили жанры без поджанра. Возможно, вместо сложного регулярного выражения имеет смысл выполнить двухэтапный сплит: сначала по ",", потом сплит или регулярка по "-".
# После заполнения признаков `genre` и `subgenre` массивами (если у жанра нет поджанра, просто проставим `None`) можно воспользоваться методом [.explode()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.explode.html).
# Далее осуществим более простой вариант: смешаем жанры и поджанры в одном признаке.

# %%
df.genre_and_votes[8]
# Out:
# 'Sequential Art-Comics,Sequential Art-Graphic Novels,Sequential Art-Bande DessinÃ©e,Fiction,Humor,Cultural-France'

# %%
df.genre_and_votes.str.findall(r'([\w ]+)')[8]
# Out:
# ['Sequential Art',
#  'Comics',
#  'Sequential Art',
#  'Graphic Novels',
#  'Sequential Art',
#  'Bande DessinÃ',
#  'e',
#  'Fiction',
#  'Humor',
#  'Cultural',
#  'France']

# %% [markdown]
# Как видно, такая конструкция выделит все слова с пробелом. Однако, поджанр "Bande DessinÃ©e" превратился в два: 'Bande DessinÃ', 'e'. К тому же мы получили дубли.

# %%
df.genre_and_votes = df.genre_and_votes.str.findall(r'([\w ]+)')

# %% [markdown]
# Избавимся от дубликатов.

# %%
# тестовая проверка
df.genre_and_votes.apply(lambda x: pd.unique(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[92], line 2
#       1 # тестовая проверка
# ----> 2 df.genre_and_votes.apply(lambda x: pd.unique(x))
#
# File c:\Users\UD\ait-ds\Lib\site-packages\pandas\core\series.py:5084, in Series.apply(self, func, args, by_row, **kwargs)
#    4960 def apply(
#    4961     self,
#    4962     func: AggFuncType,
#    (...)   4966     **kwargs,
#    4967 ) -> DataFrame | Series:
#    4968     """
#    4969     Invoke function on values of Series.
#    4970
#    (...)   5076     dtype: float64
#    5077     """
#    5078     return SeriesApply(
#    5079         self,
#    5080         func,
#    5081         by_row=by_row,
#    5082         args=args,
#    5083         kwargs=kwargs,
# -> 5084     ).apply()
#
# File c:\Users\UD\ait-ds\Lib\site-packages\pandas\core\apply.py:1520, in SeriesApply.apply(self)
#    1517     return self.apply_compat()
#    1519 # self.func is Callable
# -> 1520 return self.apply_standard()
#
# File c:\Users\UD\ait-ds\Lib\site-packages\pandas\core\apply.py:1578, in SeriesApply.apply_standard(self)
#    1576 else:
#    1577     curried = func
# -> 1578 mapped = obj._map_values(mapper=curried)
#    1580 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1581     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1582     #  See also GH#25959 regarding EA support
#    1583     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\UD\ait-ds\Lib\site-packages\pandas\core\base.py:1022, in IndexOpsMixin._map_values(self, mapper, na_action)
#    1019 if isinstance(arr, ExtensionArray):
#    1020     return arr.map(mapper, na_action=na_action)
# -> 1022 return algorithms.map_array(arr, mapper, na_action=na_action)
#
# File c:\Users\UD\ait-ds\Lib\site-packages\pandas\core\algorithms.py:1710, in map_array(arr, mapper, na_action)
#    1708 values = arr.astype(object, copy=False)
#    1709 if na_action is None:
# -> 1710     return lib.map_infer(values, mapper)
#    1711 else:
#    1712     return lib.map_infer_mask(values, mapper, mask=isna(values).view(np.uint8))
#
# File pandas/_libs/lib.pyx:3071, in pandas._libs.lib.map_infer()
#
# Cell In[92], line 2, in <lambda>(x)
#       1 # тестовая проверка
# ----> 2 df.genre_and_votes.apply(lambda x: pd.unique(x))
#
# File c:\Users\UD\ait-ds\Lib\site-packages\pandas\core\algorithms.py:433, in unique(values)
#     327 @set_module("pandas")
#     328 def unique(values):
#     329     """
#     330     Return unique values based on a hash table.
#     331
#    (...)    431     Length: 3, dtype: complex128
#     432     """
# --> 433     return unique_with_mask(values)
#
# File c:\Users\UD\ait-ds\Lib\site-packages\pandas\core\algorithms.py:461, in unique_with_mask(values, mask)
#     459 def unique_with_mask(values, mask: npt.NDArray[np.bool_] | None = None):
#     460     """See algorithms.unique for docs. Takes a mask for masked arrays."""
# --> 461     values = _ensure_arraylike(values, func_name="unique")
#     463     if isinstance(values.dtype, ExtensionDtype):
#     464         # Dispatch to extension dtype's unique.
#     465         return values.unique()
#
# File c:\Users\UD\ait-ds\Lib\site-packages\pandas\core\algorithms.py:239, in _ensure_arraylike(values, func_name)
#     232 if not isinstance(
#     233     values,
#     234     (ABCIndex, ABCSeries, ABCExtensionArray, np.ndarray, ABCNumpyExtensionArray),
#     235 ):
#     236     # GH#52986
#     237     if func_name != "isin-targets":
#     238         # Make an exception for the comps argument in isin.
# --> 239         raise TypeError(
#     240             f"{func_name} requires a Series, Index, "
#     241             f"ExtensionArray, np.ndarray or NumpyExtensionArray "
#     242             f"got {type(values).__name__}."
#     243         )
#     245     inferred = lib.infer_dtype(values, skipna=False)
#     246     if inferred in ["mixed", "string", "mixed-integer"]:
#     247         # "mixed-integer" to ensure we do not cast ["ss", 42] to str GH#22160
#
# TypeError: unique requires a Series, Index, ExtensionArray, np.ndarray or NumpyExtensionArray got list.

# %%
# фикс ворнинга
df.genre_and_votes.apply(lambda x: pd.unique(np.array(x)))
# Out:
# 0                          [Young Adult, Mystery, Romance]
# 1         [Christian Fiction, Christian, Fiction, Romance]
# 2                  [Christian Fiction, Christian, Fiction]
# 3                     [Thriller, Mystery, Horror, Fiction]
# 4        [Economics, Finance, Nonfiction, Business, Per...
#                                ...
# 52194    [Romance, Historical Romance, Historical, Adul...
# 52195    [Nonfiction, Short Stories, Writing, Essays, A...
# 52196    [Fiction, Childrens, Historical, Historical Fi...
# 52197                      [Young Adult, Mystery, Romance]
# 52198    [Biography, Nonfiction, Politics, Autobiograph...
# Name: genre_and_votes, Length: 48562, dtype: object

# %%
# внесем изменения
df.genre_and_votes = df.genre_and_votes.apply(lambda x: pd.unique(np.array(x)))
df.rename(columns = {'genre_and_votes' : 'genre'}, inplace = True)
df.genre
# Out:
# 0                          [Young Adult, Mystery, Romance]
# 1         [Christian Fiction, Christian, Fiction, Romance]
# 2                  [Christian Fiction, Christian, Fiction]
# 3                     [Thriller, Mystery, Horror, Fiction]
# 4        [Economics, Finance, Nonfiction, Business, Per...
#                                ...
# 52194    [Romance, Historical Romance, Historical, Adul...
# 52195    [Nonfiction, Short Stories, Writing, Essays, A...
# 52196    [Fiction, Childrens, Historical, Historical Fi...
# 52197                      [Young Adult, Mystery, Romance]
# 52198    [Biography, Nonfiction, Politics, Autobiograph...
# Name: genre, Length: 48562, dtype: object

# %% [markdown]
# ### 1.7 Интерактивный график в `matplotlib`
# #### Сгруппируем оценки пользователей по годам выхода книжного издания

# %%
df_ratings = df.groupby('year_published') \
    .agg({'rating_count' : 'sum',
          'five_star_ratings' : 'sum',
          'four_star_ratings': 'sum',
          'three_star_ratings': 'sum',
          'two_star_ratings': 'sum',
          'one_star_ratings': 'sum'}) \
    .reset_index()
df_ratings.describe()
# Out:
#        year_published  rating_count  five_star_ratings  four_star_ratings  three_star_ratings  two_star_ratings  one_star_ratings
# count      446.000000  4.460000e+02       4.460000e+02       4.460000e+02        4.460000e+02      4.460000e+02      4.460000e+02
# mean      1720.760090  2.197842e+06       9.107610e+05       7.281215e+05        4.021078e+05      1.087547e+05      4.809649e+04
# std        247.531332  6.586845e+06       2.762668e+06       2.178132e+06        1.187946e+06      3.294902e+05      1.512385e+05
# min       1000.000000  7.000000e+00       5.000000e+00       2.000000e+00        0.000000e+00      0.000000e+00      0.000000e+00
# 25%       1599.250000  5.066750e+03       1.689500e+03       1.403750e+03        1.058500e+03      3.190000e+02      1.122500e+02
# 50%       1796.500000  5.987000e+04       2.058500e+04       2.020150e+04        1.462200e+04      3.980500e+03      1.421000e+03
# 75%       1909.750000  9.759775e+05       3.674650e+05       3.236198e+05        1.861675e+05      5.010150e+04      1.780975e+04
# max       2021.000000  5.516730e+07       2.375305e+07       1.820474e+07        9.391810e+06      2.603820e+06      1.285149e+06

# %% [markdown]
# #### Ограничим год выхода 1800+

# %%
df_ratings = df_ratings[df_ratings.year_published > 1800]
ratings = ['five_star_ratings', 'four_star_ratings',
           'three_star_ratings', 'two_star_ratings',
           'one_star_ratings']

# %% [markdown]
# #### Количество оценок переведем в %

# %%
# show rating categories as a percentage
for ratings in ratings:
    df_ratings[ratings] = df_ratings[ratings] / df_ratings['rating_count'] * 100
df_ratings = df_ratings.reset_index(drop=True)
df_ratings.head()
# Out:
#    year_published  rating_count  five_star_ratings  four_star_ratings  three_star_ratings  two_star_ratings  one_star_ratings
# 0            1801           940          17.021277          24.042553           34.787234         18.936170          5.212766
# 1            1802          5201          20.361469          30.321092           30.186503         13.901173          5.229764
# 2            1804          2728          42.705279          33.944282           16.788856          4.802053          1.759531
# 3            1806          1570          20.191083          34.076433           30.636943         11.910828          3.184713
# 4            1807         14940          39.879518          28.929050           20.287818          7.088353          3.815261

# %% [markdown]
# #### Бэкенды `matplotlib`
#
# В качестве бэкенда для интерактивных графиков `matplotlib` в jupyter notebook'ах необходимо использовать `ipympl`:
#
# ```python
# %matplotlib ipympl
# ```
# или
#
# ```python
# %matplotlib widget
# ```
#
# Подробнее: [Interactive backends @ matplotlib](https://matplotlib.org/stable/users/explain/figure/backends.html#interactive-backends).

# %% [markdown]
# Встроенные методы построения графиков в `pandas` и часть методов в `seaborn` позволяют в качестве аргумента передать ось построения [matplotlib.axes.Axes](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.html), поэтому фигуру и оси построения можно инициализировать заранее с необходимым размером. Методы построения некоторых графиков в `seaborn` инициализируют `matplotlib.pyplot.figure` под капотом, поэтому рендер и установка размера области построения задаются по-другому. Подробнее в [Figure-level vs. axes-level functions @ seaborn](https://seaborn.pydata.org/tutorial/function_overview.html#figure-level-vs-axes-level-functions).
# > Чтобы не плодить излишнее количество фигур при повторной отрисовке (повторное выполнение ячеек с созданием нового `matplotlib.pyplot.figure`), можно предварительно "закрывать" текущую фигуру с использованием [plt.close()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.close.html):
# > ```python
# > matplotlib.pyplot.close(fig=None)
# > ```
# > > Close a figure window, and unregister it from pyplot.

# %% [markdown]
# #### Импорт библиотек

# %%
# magic function - см. Interactive Plotting in IPython
# %matplotlib inline
# %matplotlib widget
# %matplotlib ipympl
from ipywidgets import *
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from itertools import cycle
# см. https://ipython.readthedocs.io/en/stable/interactive/plotting.html
# Starting with IPython 5.0 and matplotlib 2.0 you can avoid the use of IPython’s specific magic
# and use matplotlib.pyplot.ion()/matplotlib.pyplot.ioff() which have the advantages of working outside of IPython as well.
# plt.ion()
print(mpl.get_backend())
# Out:
# widget

# %%
mpl.__version__
# Out:
# '3.10.8'

# %%
fig_ipl = None
fig_pd = None
fig_sns = None
fig_sp = None

def close_mpl_fig(figure=None, exclude_list: list[plt.figure] = []):
    fig = figure
    if fig is None:
        fig = plt.gcf()
    if fig not in exclude_list:
        plt.close(fig)

# %%
from matplotlib.widgets import Slider, Button

def mpl_iplot():
    close_mpl_fig(fig_ipl, [fig_pd, fig_sns, fig_sp])
    fig, ax = plt.subplots(figsize=(10, 7.5))
    r5 = ax.plot(list(df_ratings.year_published),
                 list(df_ratings.five_star_ratings), label = '★★★★★')
    r4 = ax.plot(list(df_ratings.year_published),
                 list(df_ratings.four_star_ratings), label = '★★★★')
    r3 = ax.plot(list(df_ratings.year_published),
                 list(df_ratings.three_star_ratings), label = '★★★')
    r2 = ax.plot(list(df_ratings.year_published),
                 list(df_ratings.two_star_ratings), label = '★★')
    r1 = ax.plot(list(df_ratings.year_published),
                 list(df_ratings.one_star_ratings), label = '★')
    plt.xlabel("Год выхода")
    plt.ylabel("% отзывов")
    plt.title("Средний пользовательский рейтинг")
    # plt.legend(loc='right', bbox_to_anchor = (1.3, 0.5))
    leg = ax.legend(loc ='right', bbox_to_anchor = (1.13, 0.5), fancybox=True, shadow=True)
    
    # adjust the main plot to make room for the sliders
    fig.subplots_adjust(bottom=0.25)
    
    ax_year = fig.add_axes([0.20, 0.1, 0.60, 0.03])
    year_slider = Slider(
        ax=ax_year,
        label='Год',
        valmin=1800,
        valmax=2020,
        valinit=1800,
        valstep = 1,
    )
    
    lines = ax.get_lines()
    lined = {}  # Will map legend lines to original lines.
    for legline, origline in zip(leg.get_lines(), lines):
        legline.set_picker(7)  # Enable picking on the legend line.
        lined[legline] = origline
    
    # The function to be called anytime a slider's value changes
    def update(val):
        ax.clear()
        year = year_slider.val
        df_ratings_year = df_ratings[df_ratings.year_published >= year]
        r5 = ax.plot(list(df_ratings_year.year_published),
                     list(df_ratings_year.five_star_ratings), label = '★★★★★');
        r4 = ax.plot(list(df_ratings_year.year_published),
                     list(df_ratings_year.four_star_ratings), label = '★★★★');
        r3 = ax.plot(list(df_ratings_year.year_published),
                     list(df_ratings_year.three_star_ratings), label = '★★★');
        r2 = ax.plot(list(df_ratings_year.year_published),
                     list(df_ratings_year.two_star_ratings), label = '★★');
        r1 = ax.plot(list(df_ratings_year.year_published),
                     list(df_ratings_year.one_star_ratings), label = '★');
        leg = ax.legend(loc ='right', bbox_to_anchor = (1.13, 0.5), fancybox=True, shadow=True)
        ax.set_xlabel("Год выхода")
        ax.set_ylabel("% отзывов")
        ax.set_title("Средний пользовательский рейтинг")
    
        lines = ax.get_lines()
        for legline, origline in zip(leg.get_lines(), lines):
            legline.set_picker(7)  # Enable picking on the legend line.
            lined[legline] = origline
    
        fig.canvas.draw_idle()
    
    def on_pick(event):
        # On the pick event, find the original line corresponding to the legend
        # proxy line, and toggle its visibility.
        legline = event.artist
        origline = lined[legline]
        visible = not origline.get_visible()
        origline.set_visible(visible)
        # Change the alpha on the line in the legend, so we can see what lines
        # have been toggled.
        legline.set_alpha(1.0 if visible else 0.2)
        # year_slider.set_cal(year_slider.val)
        fig.canvas.draw()
    
    fig.canvas.mpl_connect('pick_event', on_pick)
    
    
    # register the update function with each slider
    year_slider.on_changed(update)
    
    ax_21y = fig.add_axes([0.125, 0.9, 0.025, 0.04])
    button_21y = Button(ax_21y, '21y', hovercolor='0.975')
    
    ax_100y = fig.add_axes([0.155, 0.9, 0.025, 0.04])
    button_100y = Button(ax_100y, '100y', hovercolor='0.975')
    
    ax_ally = fig.add_axes([0.185, 0.9, 0.025, 0.04])
    button_ally = Button(ax_ally, 'ally', hovercolor='0.975')
    
    def clicked_w(year):
        def clicked(event):
            year_slider.set_val(year)
        return clicked
    
    button_21y.on_clicked(clicked_w(year=2000))
    button_100y.on_clicked(clicked_w(year=1920))
    button_ally.on_clicked(clicked_w(year=1800))
    
    resetax = fig.add_axes([0.8, 0.025, 0.1, 0.04])
    button_reset = Button(resetax, 'Reset', hovercolor='0.975')
    
    def reset(event):
        year_slider.reset()
    button_reset.on_clicked(reset)
    plt.show()
    return fig

fig_ipl = mpl_iplot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### 1.8 Интерактивный график в `plotly`
# #### Для корректного отображения в Jupyter Lab
# Deprecated:
# - [Plotly gives an empty field as output in jupyter lab @ StackOverflow](https://stackoverflow.com/a/56777278):
#    ```cmd
#    jupyter labextension install @jupyterlab/plotly-extension
#    jupyter labextension list
#    jupyter lab build
#    ```
#
# `jupyter labextension list` по прежнему выводит список расширений:
# ```cmd
# jupyterlab-execute-time           3.1.2
# jupyterlab_pygments               0.3.0
# jupyterlab_server                 2.27.1
# jupyterlab_widgets                3.0.13
# ```
#
# но устанавливать их следует через менеджер пакетов:
# ```cmd
# pip3 install jupyterlab-execute-time jupyterlab_pygments jupyterlab_server jupyterlab_widgets
# ```
#
# > After these, restart JupyterLab, and set `plotly.offline.init_notebook_mode(connected=True)` at the start of each notebook session, then `plotly.offline.iplot` should correctly display the plots in the notebook.

# %% [markdown]
# #### Импорт библиотек

# %%
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from plotly.offline import iplot, init_notebook_mode
init_notebook_mode(connected=True)
# import plotly.io as pio
# pio.renderers.default='notebook'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>

# %%
import plotly as py
py.__version__
# Out:
# '6.5.2'

# %%
fig_1 = go.Figure()

fig_1.add_trace(
    go.Scatter(x=list(df_ratings.year_published),
               y=list(df_ratings.five_star_ratings), name = '★★★★★'))
fig_1.add_trace(
    go.Scatter(x=list(df_ratings.year_published),
               y=list(df_ratings.four_star_ratings), name = '★★★★'))
fig_1.add_trace(
    go.Scatter(x=list(df_ratings.year_published),
               y=list(df_ratings.three_star_ratings), name = '★★★'))
fig_1.add_trace(
    go.Scatter(x=list(df_ratings.year_published),
               y=list(df_ratings.two_star_ratings),name = '★★'))
fig_1.add_trace(
    go.Scatter(x=list(df_ratings.year_published),
               y=list(df_ratings.one_star_ratings), name = '★'))

# Set title
fig_1.update_layout(
    title_text="Средний пользовательский рейтинг",
    title_x=0.5,
    legend_title="Рейтинг",
    legend = dict(orientation = "v", y = .5, x = 1.025)
)

# Add range slider
fig_1.update_layout(
    xaxis = dict(
        rangeselector = dict(
            buttons = list([
                dict(count = 21,
                     label = "21y",
                     step = "year",
                     stepmode = "backward"),
                dict(count = 100,
                     label = "100y",
                     step = "year",
                     stepmode = "backward"),
                dict(step = "all")
            ])
        ),
        rangeslider = dict(
            visible = True
        ),
        type = "date"
    ),
    autosize=False,
    width=1000,
    height=800,
)

fig_1.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="1ef71e22-1a47-4cd3-b350-b3f117e76187" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1ef71e22-1a47-4cd3-b350-b3f117e76187")) {                    Plotly.newPlot(                        "1ef71e22-1a47-4cd3-b350-b3f117e76187",                        [{"name":"★★★★★","x":[1801,1802,1804,1806,1807,1808,1809,1810,1811,1812,1813,1814,1815,1816,1817,1818,1819,1820,1821,1822,1823,1824,1825,1826,1827,1828,1829,1830,1831,1832,1833,1834,1835,1836,1837,1838,1839,1840,1841,1842,1843,1844,1845,1846,1847,1848,1849,1850,1851,1852,1853,1854,1855,1856,1857,1858,1859,1860,1861,1862,1863,1864,1865,1866,1867,1868,1869,1870,1871,1872,1873,1874,1875,1876,1877,1878,1879,1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1899,1900,1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[17.02127659574468,20.361468948279178,42.705278592375365,20.191082802547772,39.87951807228916,34.65326463383732,25.964912280701753,24.655355249204668,40.71629315773915,43.89231920312583,53.836673629067974,29.541401631632898,37.37110131040391,32.459280472525506,28.118479192217873,34.6002804117135,29.35987546582386,32.51586489252814,17.91641671665667,46.81647940074906,58.11876408110718,26.59103486441616,44.674096151354156,27.329602686066035,50.18786756697887,51.11842105263158,33.44418362023996,59.03795594550627,36.953678714347994,34.11842431249484,40.531900769050075,28.443547878711467,39.1457110198992,33.9377689973894,36.37127963679166,32.36180904522613,32.040288470316156,37.67371318047425,30.319270039755512,38.37630225355795,41.19163214704616,46.51079613434302,41.80027129707029,34.63059833331897,41.925928498669315,30.566186703779042,49.46074441320113,23.77603945757947,28.289529653777763,30.826666666666668,36.90944499122001,28.727710107296957,40.41680687349979,27.333841569062304,39.445731763833535,35.429386590584876,35.073182259709704,28.20768278276711,30.956241073837464,47.10003314405009,33.832562272929245,33.556340368776446,40.20860174333538,48.9404007061657,44.75100346549172,42.01889250554783,34.20972914427869,34.78457128670413,38.58253251924608,35.881033147252865,30.118580557556662,34.102562678118076,32.818454542421684,34.92909784621503,40.54300531096796,34.18688782792735,40.88984494586582,35.67930957848729,31.05931847538761,37.24097098875074,37.170861627150934,30.53956326201804,36.051299358758016,27.624349188697366,39.15909783056556,34.7182070157661,30.660658838284228,39.419732942154,35.333581710046474,43.81126595885115,32.17294356795825,40.42095989581338,33.31475067982123,30.918147021297475,34.68998729761532,27.899075908697768,24.958520787466895,35.16491448038637,39.41569152678998,41.457073371413216,34.22122476888758,37.32746788067896,41.16768360153014,32.50651412530946,34.25330113005307,47.12768087541021,40.85682419475638,42.149460116849255,33.715811909903856,34.21222949949108,38.667070715040104,41.90425228112688,34.436374426770286,34.28321597086989,40.72465010185448,35.08293101077982,38.541526921067884,33.92332259228584,38.10138566141664,39.756894199363295,43.293939538054246,36.50899785754279,35.389042589 ...

# %% [markdown]
# # 1.9 Построение графиков средствами `pandas`
# #### `hist`

# %%
close_mpl_fig(fig_pd, [fig_ipl, fig_sns, fig_sp])
ax_pd = df_ratings.hist(figsize=(10, 7.5))
fig_pd = ax_pd[0, 0].get_figure()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
close_mpl_fig(fig_pd, [fig_ipl, fig_sns, fig_sp])
ax_pd = df_ratings.hist(column='five_star_ratings', bins = 10)
fig_pd = ax_pd[0, 0].get_figure()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### 1.10 Построение графиков в `seaborn`
# #### Импорт библиотеки

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.13.2'

# %% [markdown]
# #### `boxplot`

# %%
df_ratings['five_star_ratings']
# Out:
# 0      17.021277
# 1      20.361469
# 2      42.705279
# 3      20.191083
# 4      39.879518
#          ...
# 214    40.333754
# 215    41.294209
# 216    40.775111
# 217    43.145761
# 218    66.393443
# Name: five_star_ratings, Length: 219, dtype: float64

# %%
close_mpl_fig(fig_sns, [fig_ipl, fig_pd, fig_sp])
fig_sns, ax_sns = plt.subplots(figsize=(5, 5))
sns.boxplot(ax = ax_sns, data=df_ratings['five_star_ratings'])
fig_sns.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# > [Getting Error 0 when plotting boxplot of a filtered dataset](https://stackoverflow.com/a/71423584)

# %%
close_mpl_fig(fig_sns, [fig_ipl, fig_pd, fig_sp])
fig_sns, ax_sns = plt.subplots(1, 5, figsize=(10, 5))
sns.boxplot(ax=ax_sns[0], data=df_ratings, x='five_star_ratings')
sns.boxplot(ax=ax_sns[1], data=df_ratings, x='four_star_ratings')
sns.boxplot(ax=ax_sns[2], data=df_ratings, x='three_star_ratings')
sns.boxplot(ax=ax_sns[3], data=df_ratings, x='two_star_ratings')
sns.boxplot(ax=ax_sns[4], data=df_ratings, x='one_star_ratings')
# Пример стайлинга subplot'ов - каждый ящик в свой цвет из палитры
colors = sns.color_palette('Spectral')
cycler = cycle(colors)
for ax in ax_sns:
    for p in ax.patches:
        p.set_facecolor(next(cycler))
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Ящик с усами
# [Wiki](https://ru.wikipedia.org/wiki/%D0%AF%D1%89%D0%B8%D0%BA_%D1%81_%D1%83%D1%81%D0%B0%D0%BC%D0%B8)
#
# <div align="center">
#   <img src="https://upload.wikimedia.org/wikipedia/commons/1/1a/Boxplot_vs_PDF.svg" width="66%" title="Python logo"/>
# </div>

# %% [markdown]
# # 1.11 Построение различных графиков
#
# #### Анализ жанров

# %%
genres = df['genre'].explode().value_counts().index.tolist()
genres[:10]
# Out:
# [np.str_('Fiction'),
#  np.str_('Fantasy'),
#  np.str_('Romance'),
#  np.str_('Young Adult'),
#  np.str_('Nonfiction'),
#  np.str_('Historical'),
#  np.str_('Contemporary'),
#  np.str_('Historical Fiction'),
#  np.str_('Mystery'),
#  np.str_('Paranormal')]

# %%
type(genres)
# Out:
# list

# %%
print(f"Жанров всего: {len(genres)}")
# Out:
# Жанров всего: 1403

# %% [markdown]
# Выделим топ-10 жанров и авторов.

# %%
auth = df['author'].explode().value_counts().reset_index()
auth = auth[:10]
gen = df['genre'].explode().value_counts().reset_index()
gen = gen[:10]

# %%
auth
# Out:
#             author  count
# 0     Stephen King     94
# 1     Nora Roberts     94
# 2  James Patterson     92
# 3  Agatha Christie     86
# 4      Erin Hunter     76
# 5        J.D. Robb     66
# 6        Meg Cabot     64
# 7  Terry Pratchett     64
# 8  Francine Pascal     63
# 9    Carolyn Keene     59

# %%
gen
# Out:
#                 genre  count
# 0             Fiction  24337
# 1             Fantasy  13058
# 2             Romance  12397
# 3         Young Adult   9477
# 4          Nonfiction   7722
# 5          Historical   6677
# 6        Contemporary   6183
# 7  Historical Fiction   5918
# 8             Mystery   5830
# 9          Paranormal   5028

# %%
fig_2 = make_subplots(rows=1, cols=2,
                      specs=[[{'type': 'xy'}, {"type": "xy"}]],
                      subplot_titles=("Топ 10 самых популярных жанров",
                                      "Топ 10 самых популярных авторов"))
# Setting Bar parameters
fig_2.add_trace(go.Bar(x=gen.genre,
                       y=gen['count'],
                       name ='Books',
                       marker_color=px.colors.sequential.Plasma),
                       row=1, col=1)
# Setting Bar parameters
fig_2.add_trace(go.Bar(x=auth.author,
                       y=auth['count'],
                       name ='Books',
                       marker_color=px.colors.sequential.Plotly3),
                       row=1, col=2)
# Setting the parameters of the chart when displaying
fig_2.update_traces(marker_line_width=0)

# Setting the parameters of the chart when displaying
fig_2.update_layout(showlegend=False,
                    plot_bgcolor='rgba(0,0,0,0)',
                    font=dict(family='Arial',
                              size=12,
                              color='black'),
                    autosize=False,
                    width=1100,
                    height=800,)

# Displaying the graph
fig_2.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="ead6bda3-60a9-4e12-8747-53d532181305" class="plotly-graph-div" style="height:800px; width:1100px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ead6bda3-60a9-4e12-8747-53d532181305")) {                    Plotly.newPlot(                        "ead6bda3-60a9-4e12-8747-53d532181305",                        [{"marker":{"color":["#0d0887","#46039f","#7201a8","#9c179e","#bd3786","#d8576b","#ed7953","#fb9f3a","#fdca26","#f0f921"],"line":{"width":0}},"name":"Books","x":["Fiction","Fantasy","Romance","Young Adult","Nonfiction","Historical","Contemporary","Historical Fiction","Mystery","Paranormal"],"y":{"dtype":"i2","bdata":"EV8CM20wBSUqHhUaJxgeF8YWpBM="},"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":["#0508b8","#1910d8","#3c19f0","#6b1cfb","#981cfd","#bf1cfd","#dd2bfd","#f246fe","#fc67fd","#fe88fc","#fea5fd","#febefe","#fec3fe"],"line":{"width":0}},"name":"Books","x":["Stephen King","Nora Roberts","James Patterson","Agatha Christie","Erin Hunter","J.D. Robb","Meg Cabot","Terry Pratchett","Francine Pascal","Carolyn Keene"],"y":{"dtype":"i1","bdata":"Xl5cVkxCQEA\u002fOw=="},"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern": ...

# %% [markdown]
# #### Введем искусственный признак - тип серии (цикличность)

# %%
di = {1: 'Standalone', 2: 'Duology', 3: 'Trilogy'}
df['series_type'] = df['books_in_series_count'].map(di).fillna('Saga')
df['series_type']
# Out:
# 0              Saga
# 1           Duology
# 2              Saga
# 3              Saga
# 4        Standalone
#             ...
# 52194    Standalone
# 52195    Standalone
# 52196    Standalone
# 52197          Saga
# 52198    Standalone
# Name: series_type, Length: 48562, dtype: str

# %% [markdown]
# #### Распределение по типу серии

# %%
close_mpl_fig(fig_sns, [fig_ipl, fig_pd, fig_sp])
fig_sns, ax_sns = plt.subplots(figsize=(10, 5))
sns.countplot(ax=ax_sns, data=df, x='series_type', hue='series_type', palette='coolwarm');
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Топ-10 издательств

# %%
pubs = df['publisher'].explode().value_counts().index.tolist()
pubs[:10]
# Out:
# ['Vintage',
#  'HarperCollins',
#  'Penguin Books',
#  'Ballantine Books',
#  'Bantam',
#  'Pocket Books',
#  'Avon',
#  'Berkley',
#  'Del Rey',
#  'Tor Books']

# %%
df['publisher'].value_counts().head(10)
# Out:
# publisher
# Vintage             569
# HarperCollins       559
# Penguin Books       493
# Ballantine Books    395
# Bantam              373
# Pocket Books        318
# Avon                307
# Berkley             287
# Del Rey             287
# Tor Books           282
# Name: count, dtype: int64

# %%
pubs_i = df['publisher'].value_counts().head(10).index
pubs_i
# Out:
# Index(['Vintage', 'HarperCollins', 'Penguin Books', 'Ballantine Books', 'Bantam', 'Pocket Books', 'Avon', 'Berkley', 'Del Rey', 'Tor Books'], dtype='str', name='publisher')

# %%
df_pubs = df[df['publisher'].isin(pubs_i)]
df_pubs.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 3870 entries, 3 to 52183
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      3870 non-null   int64
#  1   title                   3870 non-null   str
#  2   link                    3870 non-null   str
#  3   series                  2104 non-null   str
#  4   cover_link              3860 non-null   str
#  5   author                  3870 non-null   object
#  6   author_link             3870 non-null   str
#  7   rating_count            3870 non-null   int64
#  8   review_count            3870 non-null   int64
#  9   average_rating          3870 non-null   float64
#  10  five_star_ratings       3870 non-null   int64
#  11  four_star_ratings       3870 non-null   int64
#  12  three_star_ratings      3870 non-null   int64
#  13  two_star_ratings        3870 non-null   int64
#  14  one_star_ratings        3870 non-null   int64
#  15  number_of_pages         3844 non-null   float64
#  16  publisher               3870 non-null   str
#  17  original_title          3581 non-null   str
#  18  genre                   3870 non-null   object
#  19  isbn                    3665 non-null   str
#  20  isbn13                  3661 non-null   str
#  21  asin                    97 non-null     str
#  22  settings                1389 non-null   str
#  23  characters              1685 non-null   str
#  24  awards                  1130 non-null   str
#  25  amazon_redirect_link    3870 non-null   str
#  26  worldcat_redirect_link  3775 non-null   str
#  27  recommended_books       3859 non-null   str
#  28  books_in_series         2075 non-null   str
#  29  description             3716 non-null   str
#  30  year_published          3870 non-null   int64
#  31  books_in_series_count   3870 non-null   int64
#  32  awards_count            3870 non-null   int64
#  33  series_type             3870 non-null   str
# dtypes: float64(2), int64(11), object(2), str(19)
# memory usage: 1.0+ MB

# %% [markdown]
# #### Количество книг в топ-10 издательств

# %%
close_mpl_fig(fig_sns, [fig_ipl, fig_pd, fig_sp])
fig_sns, ax_sns = plt.subplots(figsize=(10, 5))
pal = sns.diverging_palette(120, 240, s=100, l=60, center='light', n=df_pubs['publisher'].value_counts().shape[0])
sns.countplot(ax=ax_sns, data=df_pubs, x='publisher', hue='publisher', palette=pal)
ax_sns.tick_params(axis='x', rotation=30)
fig_sns.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Количество книг в топ-10 издательств по типу серии

# %%
close_mpl_fig(fig_sns, [fig_ipl, fig_pd, fig_sp])
fig_sns, ax_sns = plt.subplots(figsize=(10, 5))
# fig_sns.show()
sns.countplot(ax=ax_sns, data=df_pubs, x='publisher', hue='series_type')
ax_sns.tick_params(axis='x', rotation=30)
fig_sns.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Топ-10 издательств по количеству оценок в определенном жанре

# %%
df_grouped_by_pub = df.groupby('publisher') \
    .agg({'title':'count',
          'average_rating':'mean',
          'rating_count': 'sum'}) \
    .reset_index()

# %%
df_pub_popular = df_grouped_by_pub.sort_values(by=['rating_count'], ascending=False)[:10]
df_pub_popular
# Out:
#                       publisher  title  average_rating  rating_count
# 6335              Penguin Books    493        3.955436      25439700
# 5004  Little, Brown and Company    177        3.880169      21155025
# 8740                    Vintage    569        3.939789      14314933
# 7402           Scholastic Press    162        4.085679      14186630
# 7427                   Scribner    165        3.913030      13617858
# 6357           Penguin Classics    263        3.937452      13457344
# 846                      Bantam    373        3.974129      13307327
# 824            Ballantine Books    395        3.959747      12543216
# 3754              HarperCollins    559        4.065081      11690798
# 3407   Grand Central Publishing    261        3.953946      11158290

# %%
def barplot_by_genre(genre):
    mask = [genre in x for x in df['genre']]
    newframe = df[mask]
    df_grouped_by_pub = newframe.groupby('publisher') \
       .agg({'title':'count', 'average_rating':'mean', 'rating_count': 'sum'}) \
       .reset_index()
    df_popular = df_grouped_by_pub.sort_values(by=['rating_count'], ascending=False)[:10]
    barplot = px.bar(data_frame = df_popular,
                     x = 'publisher',
                     y = 'rating_count',
                     labels = {'publisher': 'Издательство', 'rating_count': 'Количество оценок', 'average_rating': 'Рейтинг'},
                     color = 'average_rating',
                     opacity = 0.9,
                     orientation = 'v',
                     barmode = 'relative',
                     title = f"Топ 10 издательств по количеству оценок в жанре \"{genre}\"",
                    )
    barplot.layout.update(autosize=False,
                          width=1000,
                          height=500,
                          title_x = 0.5)
    barplot
    barplot.show()

# %%
interact(barplot_by_genre, genre=genres, df = fixed(df));
# Out:
# interactive(children=(Dropdown(description='genre', options=(np.str_('Fiction'), np.str_('Fantasy'), np.str_('…

# %%
# гистограммы с цикличной сменой цвета
feat = [f for f in df.columns if 'star' in f]
colors = cm.Reds(np.linspace(0.8, 0.3, len(feat)))
print(colors)
cycler = cycle(colors)

close_mpl_fig(fig_pd, [fig_ipl, fig_sns, fig_sp])
ax_pd = df_ratings[feat].hist(figsize=(10, 7.5));
fig_pd = ax_pd[0, 0].get_figure()
for ax in ax_pd.flatten().tolist():
    c = next(cycler)
    for p in ax.patches:
        p.set_facecolor(c)
# Out:
# [[0.73647059 0.08       0.10117647 1.        ]
#  [0.88133795 0.17700884 0.14925029 1.        ]
#  [0.96585928 0.34340638 0.24405998 1.        ]
#  [0.9867128  0.51164937 0.38615917 1.        ]
#  [0.98823529 0.67154171 0.56053825 1.        ]]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### `pairplot`

# %% [markdown]
# `pairplot` возвращает не ось построения, а объект класса [seaborn.PairGrid](https://seaborn.pydata.org/generated/seaborn.PairGrid.html), у которого есть атрибут `figure`.

# %%
close_mpl_fig(fig_sns, [fig_ipl, fig_pd, fig_sp])
g = sns.pairplot(height=2.5, data=df_ratings[feat]);
fig_sns = g.figure
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Связь рейтинга книги с количеством страниц и количеством сиквелов

# %%
series_type_anno = [('Любая', 'All'), ('Отдельная', 'Standalone'),
                    ('Дилогия', 'Duology'), ('Трилогия', 'Trilogy'),
                    ('Цикл', 'Saga')]
series_type_dict = dict()
for t in series_type_anno:
    series_type_dict[t[1]] = t[0]

toggle = widgets.ToggleButtons(options=series_type_anno,
                               description='Цикличность:',
                               disabled=False,
                               button_style='',
                               tooltips=['Любое количество книг',
                                        'Отдельная книга',
                                        'Две книги в цикле',
                                        'Три книги в цикле',
                                        'Больше книг богу книг']
                                )
def making_pages(df, toggle, label):
    df_pages = df[df['number_of_pages'] <= 1500].copy()
    if not toggle == 'All':
        mask = [toggle in x for x in df_pages['series_type']]
        colour = 'rating_count'
    else:
        mask = [True for x in df_pages['series_type']]
        colour = 'series_type'
    title = f"Зависимость рейтинга от количества страниц для цикличности \"{label}\""
    fig = px.scatter(df_pages[mask],
                     x="number_of_pages",
                     y="rating_count",
                     labels = {"number_of_pages": 'Количество страниц', "rating_count": 'Количество оценок',
                               "review_count": 'Количество рецензий', "series_type": 'Цикличность'},
                     size='review_count',
                     color="review_count",
                     hover_data=['title', 'author'],
                     facet_col="series_type",
                     title = title
                    )
    # Меняем названия subplot'ов
    fig.for_each_annotation(lambda a: a.update(text = series_type_dict[a.text.split('=')[1]]))
    # Меняем названия рядов в легенде
    # fig.for_each_trace(lambda t: t.update(name = series_type_dict[t.name],
    #                                       legendgroup = series_type_dict[t.name],
    #                                       hovertemplate = t.hovertemplate.replace(t.name, series_type_dict[t.name.split('=')[1]])
    #                                      ) if t.name != '' else '')

    fig.layout.update(autosize=False,
                      width=1300,
                      height=400,
                      title_x = 0.5)
    fig.show()

    df_scat = df_pages[mask].groupby(['year_published', 'series_type']) \
        .agg({'average_rating' : 'mean',
              'rating_count' : 'sum',
              'review_count' : 'sum'}) \
        .reset_index()
    df_scat = df_scat[df_scat.year_published > 1950]
    title = f"Средняя оценка для цикличности \"{label}\" c 1950 по 2021 гг."
    fig = px.scatter(df_scat,
                     y="average_rating",
                     x="year_published",
                     labels = {"average_rating": 'Средняя оценка', "year_published": 'Год выхода', "series_type": 'Цикличность', "rating_count": 'Количество оценок'},
                     log_x=True,
                     log_y=True,
                     color=colour,
                     size="rating_count",
                     title = title)
    fig.layout.update(autosize=False,
                      width=1000,
                      height=400,
                      title_x = 0.5)
    fig.show()

# %%
interact(making_pages, toggle = toggle, label = toggle.label, df=fixed(df));
# Out:
# interactive(children=(ToggleButtons(description='Цикличность:', options=(('Любая', 'All'), ('Отдельная', 'Stan…

# %% [markdown]
# #### `heatmap`

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 df.corr()
#
# File c:\Users\UD\ait-ds\Lib\site-packages\pandas\core\frame.py:13117, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13115 cols = data.columns
#   13116 idx = cols.copy()
# > 13117 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13119 if method == "pearson":
#   13120     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\UD\ait-ds\Lib\site-packages\pandas\core\frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2079 if dtype is not None:
#    2080     dtype = np.dtype(dtype)
# -> 2081 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2082 if result.dtype is not dtype:
#    2083     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\UD\ait-ds\Lib\site-packages\pandas\core\internals\managers.py:1847, in BlockManager.as_array(self, dtype, copy, na_value)
#    1845         arr.flags.writeable = False
#    1846 else:
# -> 1847     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1848     # The underlying data was copied within _interleave, so no need
#    1849     # to further copy if copy=True or setting na_value
#    1851 if na_value is lib.no_default:
#
# File c:\Users\UD\ait-ds\Lib\site-packages\pandas\core\internals\managers.py:1900, in BlockManager._interleave(self, dtype, na_value)
#    1894 rl = blk.mgr_locs
#    1895 if blk.is_extension:
#    1896     # Avoid implicit conversion of extension blocks to object
#    1897
#    1898     # error: Item "ndarray" of "Union[ndarray, ExtensionArray]" has no
#    1899     # attribute "to_numpy"
# -> 1900     arr = blk.values.to_numpy(  # type: ignore[union-attr]
#    1901         dtype=dtype,
#    1902         na_value=na_value,
#    1903     )
#    1904 else:
#    1905     arr = blk.get_values(dtype)
#
# File c:\Users\UD\ait-ds\Lib\site-packages\pandas\core\arrays\numpy_.py:589, in NumpyExtensionArray.to_numpy(self, dtype, copy, na_value)
#     586         result = result.view()
#     587         result.flags.writeable = False
# --> 589 result = np.asarray(result, dtype=dtype)
#     591 if copy and result is self._ndarray:
#     592     result = result.copy()
#
# ValueError: could not convert string to float: 'Inner Circle'

# %%
# фикс
# since pandas version 2.0.0 now you need to add numeric_only=True param to avoid the issue
# https://stackoverflow.com/a/76717659
df.corr(numeric_only=True)
# Out:
#                              id  rating_count  review_count  average_rating  five_star_ratings  four_star_ratings  three_star_ratings  two_star_ratings  one_star_ratings  number_of_pages  year_published  books_in_series_count  awards_count
# id                     1.000000     -0.018870      0.055714        0.140992          -0.013166          -0.018841           -0.030453         -0.025056         -0.017077        -0.023812        0.250141              -0.051632     -0.010081
# rating_count          -0.018870      1.000000      0.831896        0.033575           0.970995           0.986749            0.937906          0.854123          0.758821         0.031390       -0.040727               0.010896      0.362991
# review_count           0.055714      0.831896      1.000000        0.024583           0.778147           0.853200            0.808335          0.737092          0.618566         0.041081        0.008871              -0.016929      0.478139
# average_rating         0.140992      0.033575      0.024583        1.000000           0.056972           0.029730           -0.010951         -0.033353         -0.020523         0.146987        0.024327               0.165207     -0.008471
# five_star_ratings     -0.013166      0.970995      0.778147        0.056972           1.000000           0.931121            0.829844          0.723096          0.652092         0.033541       -0.031668               0.017074      0.348821
# four_star_ratings     -0.018841      0.986749      0.853200        0.029730           0.931121           1.000000            0.959334          0.862487          0.733489         0.031012       -0.042099               0.008962      0.368648
# three_star_ratings    -0.030453      0.937906      0.808335       -0.010951           0.829844           0.959334            1.000000          0.958384          0.831717         0.022540       -0.054645               0.002224      0.339277
# two_star_ratings      -0.025056      0.854123      0.737092       -0.033353           0.723096           0.862487            0.958384          1.000000          0.936248         0.020109       -0.049732              -0.009856      0.300122
# one_star_ratings      -0.017077      0.758821      0.618566       -0.020523           0.652092           0.733489            0.831717          0.936248          1.000000         0.019594       -0.033319              -0.007701      0.257341
# number_of_pages       -0.023812      0.031390      0.041081        0.146987           0.033541           0.031012            0.022540          0.020109          0.019594         1.000000       -0.025069               0.035776      0.034995
# year_published         0.250141     -0.040727      0.008871        0.024327          -0.031668          -0.042099           -0.054645         -0.049732         -0.033319        -0.025069        1.000000               0.067717      0.056653
# books_in_series_count -0.051632      0.010896     -0.016929        0.165207           0.017074           0.008962            0.002224         -0.009856         -0.007701         0.035776        0.067717               1.000000     -0.059126
# awards_count          -0.010081      0.362991      0.478139       -0.008471           0.348821           0.368648            0.339277          0.300122          0.257341         0.034995        0.056653              -0.059126      1.000000

# %%
close_mpl_fig(fig_sns, [fig_ipl, fig_pd, fig_sp])
fig_sns, ax_sns = plt.subplots(figsize=(11, 9))
sns.heatmap(ax = ax_sns, data = df[df.columns[~df.columns.isin(['id'])]].corr(numeric_only=True))
for item in ax_sns.get_xticklabels():
    item.set_rotation(30)
for item in ax_sns.get_yticklabels():
    item.set_rotation(30)
fig_sns.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# > Далее косяк с кривым отображением графиков без явного предварительного рендера с `fig_sns.show()` повторяется. Возможно, это косячное сочетание версии `matplotlib`, версии `seaborn` и бэкенда рендера.
# > Подробнее про бэкенды: [Backends](https://matplotlib.org/stable/users/explain/figure/backends.html).

# %% [markdown]
# #### violinplot

# %%
close_mpl_fig(fig_sns, [fig_ipl, fig_pd, fig_sp])
fig_sns, ax_sns = plt.subplots(2, 1, figsize=(10, 12))
sns.violinplot(ax = ax_sns[0], data = df_pubs, x = 'publisher', y = 'average_rating', hue = 'publisher', palette = 'Spectral');
sns.boxplot(ax = ax_sns[1], data = df_pubs, x = 'publisher', y = 'average_rating', hue = 'publisher', palette = 'Spectral');
for ax in ax_sns:
    ax.tick_params(axis='x', rotation=30)
fig_sns.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### QQ-график
# Графики Q-Q (квантиль-квантиль) сравнивают два распределения вероятностей путем построения совместных квантилей. График Q-Q используется для сравнения форм распределений, обеспечивая графическое представление того, насколько подобны или различны положение, масштаб и асимметрия двух распределений.
#
# С помощью него определяем насколько числовой признак похож на нормальное распределение. Поскольку целый ряд методов статистики предполагают, что распределение признака нормальное. QQ-график — один из способов проверить нормальность распределения.

# %%
from scipy import stats

close_mpl_fig(fig_sp, [fig_ipl, fig_pd, fig_sns])
fig_sp, ax_sp = plt.subplots(2, 1, figsize=(11, 12))
stats.probplot(df['average_rating'], dist="norm", plot=ax_sp[0])
df.hist(ax = ax_sp[1], column = 'average_rating', bins = 30);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from scipy import stats

close_mpl_fig(fig_sp, [fig_ipl, fig_pd, fig_sns])
fig_sp, ax_sp = plt.subplots(2, 1, figsize=(11, 12))
stats.probplot( df['average_rating'], dist=stats.expon, plot=ax_sp[0])
df.hist(ax = ax_sp[1], column = 'average_rating', bins = 30);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # 1.12 Экспорт в растровый и векторный форматы
# DPI - dots per inch - разрешение нашего рисунка, количество точек на дюйм. Пришло из полиграфии. "Физический" размер рисунка может оставаться таким же, а изменение `dpi` приведет к изменению размера рисунка на бумаге или в документе. 300 dpi достаточно для печати. Соответственно, комбинация `figsize=(w, h)` и `dpi=n` задает искомый размер (в документе размер рисунка можно поправить, и визуально качество не ухудшится, а вот на печати это скажется при апскейле) и разрешение (для печати и отображения).
# Рисунки, содержащие графики, желательно экспортировать в векторный формат, чтобы не страдало качество печати.

# %% [markdown]
# #### matplotlib

# %%
# Сохранение в растровый формат, matplotlib
fig_ipl.savefig(Path(data_path, 'ratings_by_year_300.png'), dpi=300)
fig_ipl.savefig(Path(data_path, 'ratings_by_year_600.png'), dpi=600)

# %%
# Сохранение в векторный формат, matplotlib
fig_ipl.savefig(Path(data_path, 'ratings_by_year.svg'), dpi=300)

# %% [markdown]
# #### plotly
# В `plotly` нет явного параметра `dpi`, есть только размер в пикселах и параметр `scale`.
# Необходимо установить пакет `kaleido`.

# %%
# Сохранение в растровый формат, plotly
import plotly
# plotly.io.kaleido.scope.mathjax=None
# fig_2.write_image(Path(data_path, 'top10_authors_and_genres.png'), format='png', engine='kaleido')
fig_2.write_image(Path(data_path, 'top10_authors_and_genres.png'), format='png')

# %%
# Сохранение в векторный формат, plotly
fig_2.write_image(Path(data_path, 'top10_authors_and_genres.svg'))

# %% [markdown]
# > В более старой версии `plotly` (&leq; 6.1.1) можно было выбрать движок рендера. Для экспорта в векторный формат использовался `kaleido`, но определенной версии, см. [Not able to save plotly plots using to_image or write_image](https://stackoverflow.com/questions/70997997/not-able-to-save-plotly-plots-using-to-image-or-write-image).
# >
# > Рабочая версия:
# > ```bash
# > pip install kaleido==0.1.0post1
# > ```
# > &nbsp;
# > И код экспорта немного отличался:
# > ```python
# > import plotly
# > plotly.io.kaleido.scope.mathjax=None
# > fig_2.write_image(Path(data_path, 'top10_authors_and_genres.png'), format='png', engine='kaleido')
# > ```
# > &nbsp;
# > В настоящее время `kaleido` используется в качестве основного движка, его API изменился. Некоторые сочетания версий `plotly` и `kaleido` не работали (Python 3.10).

# %%
# !uv pip show kaleido
# Out:
# Name: kaleido
# Version: 1.2.0
# Location: C:\Users\UD\ait-ds\Lib\site-packages
# Requires: choreographer, logistro, orjson, packaging, pytest-timeout
# Required-by:
# Using Python 3.14.3 environment at: C:\Users\UD\ait-ds

# %% [markdown]
# ### 1.13 `plotly` `Dash`
#
# - [A Minimal Dash App](https://dash.plotly.com/minimal-app)
# - [Dash in Jupyter Environments](https://dash.plotly.com/dash-in-jupyter)
# - [Dash Example Index]()
#
# `Dash` &ndash; библиотека для создания интерактивных веб-приложений и дашбордов.
#
# #### Интерактивный график 1.8 с использованием `Dash`

# %%
from dash import Dash, dcc, html, Input, Output
import plotly.graph_objects as go
import pandas as pd

app = Dash(__name__)

app.layout = html.Div(
    [
        html.H2(
            "Средний пользовательский рейтинг",
            style={
                'text-align': 'center',
                'font-family': 'Ink Free'
            }
        ),
        
        html.Div(
            [
                html.Br(),
                dcc.Checklist(
                    id="toggle-rangeslider",
                    options=[{"label": " Слайдер «Год выхода»", "value": "slider"}],
                    value=["slider"],
                    style={
                        'font-family': 'Tiger Expert',
                        'font-weight': 'bold',
                        'text-align': 'left'
                    }
                ),
                html.Br(),
                dcc.Graph(
                    id="graph",
                    style={
                        'font-weight': 'bold',
                        'font-size': '24'
                    }
                )
            ],
            style={
                "display": "flex", 
                'align-items': 'left',
                'flex-direction': 'column'
            }
        ),
    ], style={
        'background-color': 'rgba(180, 180, 180, 0.5)',
        'display': 'flex',
        'align-items': 'center',
        'flex-direction': 'column'
    }
)


@app.callback(
    Output("graph", "figure"),
    Input("toggle-rangeslider", "value"),
)
def display_scatter(value):
    fig_1 = go.Figure()

    fig_1.add_trace(
        go.Scatter(x=list(df_ratings.year_published),
                   y=list(df_ratings.five_star_ratings), name = '★★★★★'))
    fig_1.add_trace(
        go.Scatter(x=list(df_ratings.year_published),
                   y=list(df_ratings.four_star_ratings), name = '★★★★'))
    fig_1.add_trace(
        go.Scatter(x=list(df_ratings.year_published),
                   y=list(df_ratings.three_star_ratings), name = '★★★'))
    fig_1.add_trace(
        go.Scatter(x=list(df_ratings.year_published),
                   y=list(df_ratings.two_star_ratings),name = '★★'))
    fig_1.add_trace(
        go.Scatter(x=list(df_ratings.year_published),
                   y=list(df_ratings.one_star_ratings), name = '★'))

    # Set title
    fig_1.update_layout(
        # title_text="Средний пользовательский рейтинг",
        title_x=0.5,
        legend_title="Рейтинг",
        legend = dict(orientation = "v", y = .5, x = 1.025),
        font_family = 'Ink Free'
    )

    # Add range slider
    fig_1.update_layout(
        xaxis = dict(
            rangeselector = dict(
                buttons = list([
                    dict(count = 21,
                         label = "21y",
                         step = "year",
                         stepmode = "backward"),
                    dict(count = 100,
                         label = "100y",
                         step = "year",
                         stepmode = "backward"),
                    dict(step = "all")
                ])
            ),
            rangeslider = dict(
                visible = "slider" in value
            ),
            type = "date"
        ),
        autosize=False,
        width=1000,
        height=800,
    )

    return  fig_1


if __name__ == "__main__":
    app.run(debug=True, mode='jupyterlab')
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
